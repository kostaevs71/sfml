# %% [markdown]
# Давайте решим следующую задачу.<br>
# Необходимо написать робота, который будет скачивать новости с сайта Лента.Ру и фильтровать их в зависимости от интересов пользователя. От пользователя требуется отмечать интересующие его новости, по которым система будет выделять области его интересов.<br>

# %% [markdown]
# Начнем с загрузки новостей. Для этого нам потребуется метод requests.get(url). Библиотека requests предоставляет серьезные возможности для загрузки информации из Интернет. Метод get получает URL стараницы и возвращает ее содержимое. В нашем случае результат будет получаться в формате html. <br>
# Загрузим необходимые библиотеки.

# %%
import requests # Загрузка новостей с сайта.
from bs4 import BeautifulSoup # Превращалка html в текст.
import re # Регулярные выражения.

# %% [markdown]
# Теперь попробуем загрузить страницу новостей.

# %%
requests.get("http://lenta.ru/")
# Out:
# <Response [200]>

# %% [markdown]
# Метод <i>requests.get()</i> возвращает объект Response, который содержит большое количество различной информации о загруженной (или незагруженной) странице. В краткой форме отображается только результат выполения запроса. В нашем случае это 200, нет ошибки.<br>
# Посмотрим что результат содержит еще.

# %%
# %%time
resp=requests.get("https://nplus1.ru/news/2018/08/28/yandex-self-driving")
#resp=requests.get("https://lenta.ru/news/2018/08/24/clon/")
print("cookies:", resp.cookies)
print("time to download:", resp.elapsed)
print("page encoding", resp.encoding)
print("Server response: ", resp.status_code)
print("Is everything ok? ", resp.ok)
print("Page's URL: ", resp.url)
# Out:
# cookies: <RequestsCookieJar[<Cookie XSRF-TOKEN= for nplus1.ru/>, <Cookie laravel_session=%3D%3D for nplus1.ru/>]>
# time to download: 0:00:00.231685
# page encoding UTF-8
# Server response:  200
# Is everything ok?  True
# Page's URL:  https://nplus1.ru/news/2018/08/28/yandex-self-driving
# CPU times: user 28.1 ms, sys: 3.81 ms, total: 31.9 ms
# Wall time: 240 ms

# %% [markdown]
# Но самое для нас интересное хранится в поле <i>text</i>, которое содержит собственно текст html-страницы.

# %%
resp.text[:1000]
# Out:
# '<!doctype html>\n<html class="no-js bg-fixed _no-bg" style="background-image:url(https://nplus1.ru/images/2018/08/28/d1a45e4b99c9a988a07ab60414233ab0.jpeg)" lang="">\n<head>\n    <meta charset="utf-8">\n    <meta http-equiv="x-ua-compatible" content="ie=edge">\n    <meta name="viewport" content="width=device-width, initial-scale=1">\n    <link rel="apple-touch-icon" href="apple-touch-icon.png">\n    <meta name="apple-mobile-web-app-capable" content="yes">\n    <meta name="apple-mobile-web-app-status-bar-style" content="black">\n            <meta name="yandex-verification" content="5cb1f59ae9eddd88" /> \n    \n    <link rel="canonical" href="http://nplus1.ru/news/2018/08/28/yandex-self-driving" />\n\n        <title>&laquo;Яндекс&raquo; запустил в Иннополисе сервис беспилотного такси</title>\n\n    \t    <meta itemprop="datePublished" content="2018-08-28"/>\n\t\n\t    <meta name="mediator_author" content="Григорий Копиев"/> \n\t\n\n        <!-- for Google -->\n        <meta name="description" content="&laquo;Янд'

# %% [markdown]
# Количество служебной информации в странице явно превышает объем текста новости. У нас есть два пути: либо использовать библиотеку BeautyfulSoup для получения текста статьи, либо получить текст с использованием регулярных выражений.<br>
# Опробуем первый путь. Документация на библиотеку BeautyfulSoup находится <a href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/">здесь</a>.

# %%
BeautifulSoup(resp.text, "html5lib").get_text()
# Out:
# '\n    \n    \n    \n    \n    \n    \n             \n    \n    \n\n        «Яндекс» запустил в Иннополисе сервис беспилотного такси\n\n    \t    \n\t\n\t     \n\t\n\n        \n        \n        \n        \n        \n\n        \n        \n                \n        \n        \n        \n        \n        \n        \n        \n        \n        \n\n    \n    \n    \n    \n    \n    \n    \n\n         \n    \n             \n\t\t \n                \t    \n\t\t\n\t\t\n\t\t\n\t\t    var __colAdLoaded = false;\n\t\t    var __topAdLoaded = false;\n\t\t    \n\t\t    var __id = "";\n\t\t    \n\t\t    function detectAd(id){\n\t\t        var _ad = document.getElementById("AdFox_banner_"+id);\n\t\t    \t    console.debug(_ad);\n\t\t        \n\t\t        __id = id;\n\t\t        if(_ad != null && _ad.innerHTML == ""){\n\t\t            $(".col-ad").remove();\n\t\t        }\n\t\t        __colAdLoaded = true;\n\t\t    }\n\t\t    function detectAdTop(id){\n\t\t        __topAdLoaded = true;\n\t\t    }\n\t\t\n\t\t\n\t\t\n\t\t\n\t\t    \n\n\n(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\nnew Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\nj=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n\'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n})(window,document,\'script\',\'dataLayer\',\'GTM-MNJC58\');\n\n    \n\n\n\n\n_cookies_policy = {dark:0,bottom:1,text:\'Этот сайт использует cookies для улучшения качества работы\',link:\'Подробнее\',href:\'https://nplus1.ru/cookies-policy\',button:\'Закрыть\'};\n\n\n\n\n\n<iframe src="https://www.googletagmanager.com/ns.html?id=GTM-MNJC58"\nheight="0" width="0" style="display:none;visibility:hidden"></iframe>\n\n\n\n\n\n    \n\t\n        \n        \n                                                    \n                    \n    \n    \n                        \t                            \n        \n        \n            \n            \n                \n                \n                \n                \n                    \n                        \n                    \n                    ×\n                \n            \n            \n    \n                \n            Астрономия\n            \n                \n            Физика\n            \n                \n            Биология\n            \n                \n            Роботы и дроны\n            \n        \n                                    \n                    Давайте разберемся\n                \n                            \n                    Блокчейн\n                \n                            \n                    Издательство Яндекса\n                \n                            \n                    Краткий курс по литэкономии\n                \n                    \n            \n\n\n        \n        \n    \n        \n            \n                        \n    \n        \n        \n            \n        \n        \n            \n                \n                    \n                \n                ×\n            \n            \n            \n    \n                \n            Астрономия\n            \n                \n            Физика\n            \n                \n            Биология\n            \n                \n            Роботы и дроны\n            \n        \n        \n                \n            \n        \n            \n            \n    \n                \n            Давайте разберемся\n            \n                \n            Блокчейн\n            \n                \n            Издательство Яндекса\n            \n                \n            Краткий курс по литэкономии\n            \n            \n            \n        \n    \n        \n        \n                                            \n                    \n                \n                                \n                    Премия «Просветитель»\n                    «Воля и самоконтроль: Как гены и мозг мешают нам бороться с соблазна ...

# %% [markdown]
# Да, убрать html-теги получилось. Но их содержимое осталось, в том числе и скрипты.<br>
# Опробуем другой путь. Весь текст обычно оформляется тегом параграфа - &lt;p&gt;. Выберем весь текст из этих тегов. Заодно выберем и заголовок статьи, оформленный при помощи <h1>

# %%
bs=BeautifulSoup(resp.text, "html5lib") 
title=bs.h1.text
text=BeautifulSoup(" ".join([p.text for p in bs.find_all("p")]), "html5lib").get_text()
print(title, "\n-----\n", text)
# Out:
# «Яндекс» запустил в Иннополисе сервис беспилотного такси
# -----
#  Транспорт
#
#
#
#                     11:43
#                     28 Авг. 2018
#
#
#
#
#                 Сложность
#                 1.8
#
#           Яндекс Компания «Яндекс» запустила в городе Иннополис в Татарстане тестовый сервис беспилотного такси. Жители города могут вызвать один из двух автомобилей через бота в Telegram и перемещаться между пятью точками высадки и посадки. Во время поездок на переднем пассажирском сиденье будет присутствовать инженер компании, сообщается в блоге «Яндекса». Большинство крупных разработчиков беспилотных автомобилей, к примеру, Waymo и Uber, изначально собираются использовать их в качестве автомобилей для сервисов такси. Во многом это обусловлено тем, что, как правило, в беспилотных автомобилях установлено сразу несколько дорогих лидаров, а также мощные вычислительные модули для обработки данных в реальном времени, из-за чего на начальном этапе развития беспилотных автомобилей они будут слишком дороги для личного владения.  «Яндекс», которая представила свой беспилотный автомобиль в мае 2017 года, также запустила тестовый сервис беспилотного такси. Пока в тестировании участвуют два автомобиля компании, основанные на Toyota Prius. Жители города, зарегистрировавшиеся в программе тестирования, могут вызвать автомобиль через бота в Telegram в одной из пяти точек, предназначенных для высадки и посадки пассажиров. При этом во время пилотного проекта все поездки будут бесплатными.  Зоны посадки и высадки пассажиров беспилотного такси Яндекс   Компания объявила, что пилотный проект в Иннополисе запущен в рамках соглашения о развитии беспилотного транспорта в Татарстане, подписанного с правительством республики. Ранее «Яндекс» уже начал тестировать свои беспилотные автомобили на дорогах общего пользования Москвы, а затем один из них совершил поездку из Москвы в Казань, во время которой 99 процентов пути были пройдены в режиме автопилота. Сервисы беспилотного такси активно развиваются в США. Например, в 2017 году компания Waymo, ставшая продолжением проекта беспилотных автомобилей в Google, запустила закрытую версию сервиса беспилотного такси, в котором пассажирами являются добровольцы, не работающие в компании. А в конце 2018 года Waymo планирует запустить в Аризоне публично доступный сервис и уже заключила соглашение на поставку 62 тысяч автомобилей для этого. Кроме того, недавно сервис беспилотного такси в штате Техас запустил стартап Drive.ai. Григорий Копиев Нашли опечатку? Выделите фрагмент и нажмите Ctrl+Enter. Оставьте ваш e-mail, чтобы получатьнаш научный дайджест Предоставляя адрес электронной почты, вы принимаете условия соглашения о персональных данных. О чем говорят «разоблачения» научных результатов, оказавшихся невоспроизводимыми Коэффициент сложности Коэффициент сложности Коэффициент сложности Коэффициент сложности Коэффициент сложности Коэффициент сложности Коэффициент сложности Коэффициент сложности Коэффициент сложности Коэффициент сложности © 2018 N+1 Интернет-издание   Свидетельство о регистрации СМИ Эл № ФС77-67614 Использование всех текстовых материалов без изменений в некоммерческих целях разрешается со ссылкой на N+1.
#                         Все аудиовизуальные произведения являются собственностью своих авторов и правообладателей и используются
#                         только в образовательных и информационных целях. Если вы являетесь собственником того или иного произведения
#                         и не согласны с его размещением на нашем сайте, пожалуйста, напишите на kirill@nplus1.ru Сайт может содержать контент, не предназначенный для лиц младше 18 лет.
#                         Политика обработки персональных данных пользователей сайта
#
#
#                         Change privacy settings

# %% [markdown]
# Получилось хорошо. Но опробуем второй путь.<br>
# Теперь попробуем использовать регулярные выражения в два шага. На первом мы вырежем только саму новость с ее оформлением используя для этого регулярные выражения (библиотека re). На втором шаге мы используем библиотеку BeautifulSoup для "выкусывания" тегов html.

# %%
findheaders = re.compile("<h1.+?>(.+)</h1>", re.S)
boa = re.compile('<div class="b-text clearfix js-topic__text" itemprop="articleBody">', re.S)
eoa = re.compile('<div class="b-box">\s*?<i>', re.S)
delscript = re.compile("<script.*?>.+?</script>", re.S)

# Получает текст страницы.
art=requests.get("https://nplus1.ru/news/2018/08/28/yandex-self-driving")
# Находим заголовок.
title = findheaders.findall(art.text)[0]
# Выделяем текст новости.
text = eoa.split(boa.split(art.text)[1])
# Иногда новость оканчивается другим набором тегов.
if len(text)==1:
    text = re.split('<div itemprop="author" itemscope=""', text[0])
# Выкусываем скрипты - BeautifulSoup не справляетсяя с ними.
text = "".join(delscript.split(text[0]))
# Выкусываем остальные теги.
print(BeautifulSoup(title+"\n-----\n"+text,"html5lib").get_text())
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-44-d501d14bea0d> in <module>()
#       7 art=requests.get("https://nplus1.ru/news/2018/08/28/yandex-self-driving")
#       8 # Находим заголовок.
# ----> 9 title = findheaders.findall(art.text)[0]
#      10 # Выделяем текст новости.
#      11 text = eoa.split(boa.split(art.text)[1])
#
# IndexError: list index out of range

# %% [markdown]
# Обратите внимание на этот фрагмент.<br>
# <i>... видимых повреждений на теле не было.У трупа были взяты образцы шерсти...</i><br>
# BeautyfulSoup именно "выкусывает" теги, не заменяя их на пробелы. Иногда это можжет приводить к искожению текста из-за "склеивания" слов.

# %% [markdown]
# <font color="red" size="6">Закрепим пройденный материал выполнением небольшого задания.</text>

# %% [markdown]
# Теперь напишем функцию, которая выгружает все новости за сутки. <br>
# Обратим внимание, что для сайта Lenta.ru можно написать адрес в формате lenta.ru/ГГГГ/ММ/ДД/ (год, месяц, день) и получить все новости за этот день. Попробуем получить все адреса с такой страницы.

# %%
BeautifulSoup(requests.get("http://lenta.ru/2018/08/25/").text, "html5lib").find_all("a")
# Out:
# [<a class="b-sidebar-menu__auth-link" href="/auth/signin/"><div class="b-sidebar-menu__auth-avatar"><svg class="svg-icons__user b-sidebar-menu__auth-avatar-icon"><use xlink:href="#ui-user"></use></svg></div></a>,
#  <a href="/" style="color: #ffffff">Главное</a>,
#  <a href="/rubrics/russia/" style="color: #ffffff">Россия</a>,
#  <a href="/rubrics/world/" style="color: #ffffff">Мир</a>,
#  <a href="/rubrics/ussr/" style="color: #ffffff">Бывший СССР</a>,
#  <a href="/rubrics/economics/" style="color: #ffffff">Экономика</a>,
#  <a href="/rubrics/forces/" style="color: #ffffff">Силовые структуры</a>,
#  <a href="/rubrics/science/" style="color: #ffffff">Наука и техника</a>,
#  <a href="/rubrics/culture/" style="color: #ffffff">Культура</a>,
#  <a href="/rubrics/sport/" style="color: #ffffff">Спорт</a>,
#  <a href="/rubrics/media/" style="color: #ffffff">Интернет и СМИ</a>,
#  <a href="/rubrics/style/" style="color: #ffffff">Ценности </a>,
#  <a href="/rubrics/travel/" style="color: #ffffff">Путешествия</a>,
#  <a href="/rubrics/life/" style="color: #ffffff">Из жизни</a>,
#  <a href="http://lenta.ru/info/posts/2dev" style="color: #ce3535">Вакансия</a>,
#  <a href="http://motor.ru/" style="color: #959595" target="_blank">Мотор</a>,
#  <a href="http://dom.lenta.ru/" style="color: #959595" target="_blank">Дом</a>,
#  <a href="/parts/text/" style="color: #959595">Статьи</a>,
#  <a href="/parts/photo/" style="color: #959595">Галереи</a>,
#  <a href="/parts/video/" style="color: #959595">Видео</a>,
#  <a href="/specprojects/" style="color: #959595">Спецпроекты</a>,
#  <a class="b-sidebar-menu__search-button" onclick="$(this).closest('form').submit()"><svg class="b-sidebar-menu__search-icon"><use xlink:href="#ui-search"></use></svg></a>,
#  <a class="b-socials-subscribe__link _vk" href="https://vk.com/lentaru?utm_source=lentasocialbuttons&amp;utm_campaign=vk" target="_blank"><svg class="b-socials-subscribe__icon _vk"><use xlink:href="#ui-social-vk"></use></svg></a>,
#  <a class="b-socials-subscribe__link _fb" href="https://facebook.com/lenta.ru?utm_source=lentasocialbuttons&amp;utm_campaign=fb" target="_blank"><svg class="b-socials-subscribe__icon _fb"><use xlink:href="#ui-social-fb"></use></svg></a>,
#  <a class="b-socials-subscribe__link _tw" href="https://twitter.com/lentaruofficial?utm_source=lentasocialbuttons&amp;utm_campaign=tw" target="_blank"><svg class="b-socials-subscribe__icon _tw"><use xlink:href="#ui-social-tw"></use></svg></a>,
#  <a class="b-socials-subscribe__link _ok" href="https://ok.ru/lentaru/?utm_source=lentasocialbuttons&amp;utm_campaign=ok" target="_blank"><svg class="b-socials-subscribe__icon _ok"><use xlink:href="#ui-social-ok"></use></svg></a>,
#  <a class="b-socials-subscribe__link _yb" href="https://www.youtube.com/channel/UCfqU-kKXq868D6d4fy8fhkA?utm_source=lentasocialbuttons&amp;utm_campaign=youtube" target="_blank"><svg class="b-socials-subscribe__icon _yb"><use xlink:href="#ui-social-yb"></use></svg></a>,
#  <a class="b-socials-subscribe__link _tg" href="https://t.me/lentadnya/?utm_source=lentasocialbuttons&amp;utm_campaign=tlgrm" target="_blank"><svg class="b-socials-subscribe__icon _tg"><use xlink:href="#ui-social-tg"></use></svg></a>,
#  <a class="b-header-inner__logo" href="/"><svg class="b-header-inner__logo-icon"><use xlink:href="#ui-logo"></use></svg></a>,
#  <a class="js-calendar" href="/2018/08/25/"><span class="b-archive__header-date-select">Выбрать дату</span></a>,
#  <a class="control_mini" href="/2018/08/24/"><svg class="control_mini-icon control_mini-icon-prev"><use xlink:href="#ui-arrow-block_up"></use></svg></a>,
#  <a class="control_mini" href="/2018/08/26/"><svg class="control_mini-icon control_mini-icon-next"><use xlink:href="#ui-arrow-block_up"></use></svg></a>,
#  <a class="rubric item__rubric" href="/rubrics/forces/">Силовые структуры</a>,
#  <a class="js-dh picture" href="/articles/2018/08/25/shishkan/"><img alt="Олег Шишканов" class="g-picture" height="200" src="https://icdn.lenta.ru/images/2018/08/24/17/20180824175712919/top7_303c1fe03b7498103b0b3d30ede66309.jpg" style="max-width: 300px; width: 300px; height: 200px;" width="300"/></a>,
#  <a href="/articles/2018/08/25/shishkan/"><span>Король Шишкан</span></a>,
#  <a class="rubric item__rubric" href="/rubrics/life/">Из жизни</a>,
#  <a class="js-dh b-badge picture" href="/photo/2018/08/25/chicken/"><img alt="" class="g-picture" height="200" src="https://icdn.lenta.ru/images/2018/08/22/15/20180822151545971/top7_4b9da23f5fcdca56ef455cb3cc81e52b.jpg" style="max-width: 300px; width: 300px; height: 200px;" width="300"/><svg class="b-badge__icon"><use xlink:href="#ui-badge-photo"></use></svg></a>,
#  <a href="/photo/2018/08/25/chicken/"><span>Кость в горле</span></a>,
#  <a class="rubric item__rubric" href="/rubrics/ussr/">Бывший СССР</a>,
#  <a class="js-dh b-badge picture" href="/photo/2018/08/25/ukrparad/"><img alt="" class="g-picture" height="200" src="https://icdn.lenta.ru/images/2018/08/24/18/20180824181208831/top7_17da5ae244e213d83c360a3cfc28c2cb.jpg" style="max-width: 300px; width: 300px; height: 200px;" width="300"/><svg class="b-badge__icon"><use xlink:href="#ui-badge-photo"></use></svg></a>,
#  <a href="/photo/2018/08/25/ukrparad/"><span>Вся украинская рать</span></a>,
#  <a class="rubric item__rubric" href="/rubrics/sport/">Спорт</a>,
#  <a class="js-dh picture" href="/articles/2018/08/25/dzyuba/"><img alt="" class="g-picture" height="200" src="https://icdn.lenta.ru/images/2018/08/24/14/20180824145845129/top7_08ded42a31705ddde123b8321dc13385.jpg" style="max-width: 300px; width: 300px; height: 200px;" width="300"/></a>,
#  <a href="/articles/2018/08/25/dzyuba/"><span>В зените славы</span></a>,
#  <a class="rubric item__rubric" href="/rubrics/travel/">Путешествия</a>,
#  <a class="js-dh picture" href="/articles/2018/08/25/berlin/"><img alt="Отдыхающие на набережной Шпрее в жаркий летний день. Берлин, Германия" class="g-picture" height="200" src="https://icdn.lenta.ru/images/2018/08/17/17/20180817173728687/top7_696fbd0fa8405814def92995b441dffd.jpg" style="max-width: 300px; width: 300px; height: 200px;" width="300"/></a>,
#  <a href="/articles/2018/08/25/berlin/"><span>На Берлин!</span></a>,
#  <a class="rubric item__rubric" href="/rubrics/style/">Ценности</a>,
#  <a class="js-dh b-badge picture" href="/photo/2018/08/25/school_children/"><img alt="" class="g-picture" height="200" src="https://icdn.lenta.ru/images/2018/08/24/17/20180824172402721/top7_1cb6fd3150d3cc2e2e8b68e080576e7a.jpg" style="max-width: 300px; width: 300px; height: 200px;" width="300"/><svg class="b-badge__icon"><use xlink:href="#ui-badge-photo"></use></svg></a>,
#  <a href="/photo/2018/08/25/school_children/"><span>Классное чтение</span></a>,
#  <a class="rubric item__rubric" href="/rubrics/culture/">Культура</a>,
#  <a class="js-dh b-badge picture" href="/brief/2018/08/25/slepakovvsshnur/"><img alt="Семен Слепаков" class="g-picture" height="200" src="https://icdn.lenta.ru/images/2018/08/24/20/20180824205310152/top7_6ec8365f8a394a45f4fe2fca7601932d.png" style="max-width: 300px; width: 300px; height: 200px;" width="300"/><svg class="b-badge__icon"><use xlink:href="#ui-badge-brief"></use></svg></a>,
#  <a href="/brief/2018/08/25/slepakovvsshnur/"><span>Воспели Москву</span></a>,
#  <a href="/news/2018/08/25/potomu/"><span>На Украине объяснили отказ забирать корабли из Крыма</span></a>,
#  <a href="/news/2018/08/25/rastvorova/"><span>Умерла олимпийская чемпионка Валентина Растворова</span></a>,
#  <a href="/news/2018/08/25/razvedka/"><span>Американские осведомители в Кремле замолчали</span></a>,
#  <a href="/news/2018/08/25/poezd/"><span>Пассажирский поезд сошел с рельсов в Марселе</span></a>,
#  <a href="/news/2018/08/25/bolton/"><span>США пригрозили «еще более мощным» ударом по Сирии</span></a>,
#  <a href="/news/2018/08/25/nur/"><span>Нурмагомедов ответил Макгрегору на оскорбление отца</span></a>,
#  <a href="/news/2018/08/25/firetornado/"><span>Американец рассказал о бегстве от огненного торнадо на горящем пикапе</span></a>,
#  <a href="/news/2018/08/25/drake/"><span>Рэпер Дрейк захотел завладеть «Торонто»</span></a>,
#  <a href="/news/2018/08/25/merkel/"><span>Меркель посмотрела в бинокль на «войска Путина»</span></a>,
#  <a href="/news/2018/08/25/serena/"><span>Серене Уильямс запретили выступать в костюме кошки</span></a>,
#  <a href="/news/2018/08/25/python/"><span>Соседи убили и съели проглотившего их козу питона</span></a>,
#  <a href="/news/2018/08/25/ukrain/"><span>Украина заняла сотни миллионов долларов под высокий процент</span></a>,
#  <a href="/news/2018/08/25/vsetaki_pustili/"><span>Представителей ОБСЕ пустили к морякам задержанного на Украине российского судна</span></a>,
#  <a href="/news/2018/08/25/boycott_curtis/"><span>Боксер сдался без единого удара и захотел уважения</span></a>,
#  <a href="/news/2018/08/25/twitterrr/"><span>Конгресс США допросит главу Twitter</span></a>,
#  <a href="/news/2018/08/25/milliardy/"><span>По факту пропажи изъятых миллиардов полковника Захарченко завели дело</span></a>,
#  <a href="/news/2018/08/25/otrajenie/"><span>Живущее своей жизнью отражение в зеркале напугало пользователей сети</span></a>,
#  <a href="/news/2018/08/25/dope_ioc/"><span>Глава МОК признал непобедимость допинга</span></a>,
#  <a href="/news/2018/08/25/edro/"><span>Две тонны кокаина с логотипом «Единой России» перехватили в Бельгии</span></a>,
#  <a href="/news/2018/08/25/galaktika_v_opasnosti/"><span>Работу над «Стражами галактики» приостановили</span></a>,
#  <a href="/news/2018/08/25/seady_steady/"><span>США приготовились к мощному удару по Сирии</span></a>,
#  <a href="/news/2018/08/25/nurma/"><span>Отец Нурмагомедова отреагировал на оскорбления от Макгрегора</span></a>,
#  <a href="/news/2018/08/25/chetvero_smelyh/"><span>Четыре жителя Москвы обналичили миллиард рублей и поплатились</span></a>,
#  <a href="/news/2018/08/25/binoculars/"><span>Меркель сочли вуайеристкой</span></a>,
#  <a href="/news/2018/08/25/rybakii/"><span>Рыбаки из Северной Кореи потерялись в Японском море</span></a>,
#  <a href="/news/2018/08/25/ron_boost/"><span>Акции «Ювентуса» взлетели после перехода Роналду</span></a>,
#  <a href="/news/2018/08/25/hvastun/"><span>Порошенко похвастался нарощенными крепкими мышцами</span></a>,
#  <a href="/news/2018/08/25/hi/"><span>Собчак прикрыла гениталии книжкой о Гитлере и разъярила подписчиков</span></a>,
#  <a href="/news/2018/08/25/revenko/"><span>В «Единой России» прокомментировали перехват кокаина с логотипом партии</span></a>,
#  <a href="/news/2018/08/25/body/"><span>Тело россиянки 30 лет пролежало на Эльбрусе</span></a>,
#  <a href="/news/2018/08/25/terrorr/"><span>Власти Йемена заявили о смерти лидера «Аль-Каиды»</span></a>,
#  <a href="/news/2018/08/25/joejoe_rip/"><span>Умерла самая известная на планете капибара</span></a>,
#  <a href="/news/2018/08/25/ibra/"><span>Гол Ибрагимовича засчитали только после видеоповтора</span></a>,
#  <a href="/news/2018/08/25/bird/"><span>Крупная птица пробила крыло самолета с российскими курортниками</span></a>,
#  <a href="/news/2018/08/25/kneissl/"><span>Глава МИД Австрии объяснила поклон Путину на собственной свадьбе</span></a>,
#  <a href="/news/2018/08/25/sledcom/"><span>Александр Бастрыкин проведет два внеплановых приема граждан</span></a>,
#  <a href="/news/2018/08/25/pregnancy/"><span>Беременным в СИЗО урезали рацион</span></a>,
#  <a href="/news/2018/08/25/new_arena/"><span>В Петербурге появится новая спортивная арена стоимостью в миллиарды</span></a>,
#  <a href="/news/2018/08/25/edro_meme/"><span>В сети призвали вернуть кокаин депутатам</span></a>,
#  <a href="/news/2018/08/25/plita/"><span>С детской площадки в Самаре убрали могильную плиту</span></a>,
#  <a href="/news/2018/08/25/mcgregor_caucas/"><span>Макгрегор порассуждал о нравах кавказцев</span></a>,
#  <a href="/news/2018/08/25/batut/"><span>Россияне устроили массовую драку из-за батута</span></a>,
#  <a href="/news/2018/08/25/vegan/"><span>Фестиваль веганов отменили из-за угроз охотников и мясников</span></a>,
#  <a href="/news/2018/08/25/spartak_dinamo/"><span>Вратарь «Спартака» пропустил мяч после удара с чужой половины поля</span></a>,
#  <a href="/news/2018/08/25/train/"><span>В сети высмеяли дырявый украинский поезд</span></a>,
#  <a href="/news/2018/08/25/ronaldo_blocks/"><span>Роналду заблокировал собственный удар по пустым воротам с метра</span></a>,
#  <a href="/news/2018/08/25/kiev/"><span>В Киеве призвали распространить украинский язык до Дальнего Востока</span></a>,
#  <a href="/news/2018/08/25/fcb/"><span>Сотрудника ФСБ задержали с 8 килограммами наркотиков в колесах машины</span></a>,
#  <a href="/news/2018/08/25/kyle/"><span>Вокалист группы We Came as Romans умер в 28 лет</span></a>,
#  <a href="/news/2018/08/25/provacation/"><span>В России назвали перехват Бе-12 опасным</span></a>,
#  <a href="/rubrics/russia/">Россия</a>,
#  <a data-partslug="text" href="/articles/2018/08/28/tamplers/"><img alt="" class="g-picture" height="64" src="https://icdn.lenta.ru/images/2018/08/27/19/20180827195718474/tabloid_23ebb6e68df7cf891f1156974238efa8.jpg" style="max-width: 96px; width: 96px; height: 64px;" width="96"/><span class="b-tabloid__headline">«Москва построена на наши сокровища»</span><div class="rightcol">Рыцари таинственного ордена рассеялись по миру. Теперь они патриоты России</div></a>,
#  <a href="/news/2018/08/28/ne_brat/">Обвиняемая в экстремизме за мемы поймала судью на расизме</a>,
#  <a data-partslug="text" href="/articles/2018/08/21/alert/"><img alt="" class="g-picture" height="64" src="https://icdn.lenta.ru/images/2018/08/16/18/20180816184931041/tabloid_254c2970d809429f116ca74b1990e050.jpg" style="max-width: 96px; width: 96px; height: 64px;" width="96"/><span class="b-tabloid__headline">«Когда отец узнал, он пошел с ножом его искать»</span><div class="rightcol">Спустя многие годы жертвы педофилов рассказывают свои истории</div></a>,
#  <a href="/news/2018/08/28/kirienko_dagestan/">Кириенко высоко оценил управленческий резерв Дагестана</a>,
#  <a href="/news/2018/08/28/general/">Путин уволил 15 генералов</a>,
#  <a href="/news/2018/08/28/plati_za_repost/">ЕСПЧ обязал Россию заплатить первому осужденному за комментарий блогеру</a>,
#  <a href="/news/2018/08/28/kyrtka_putina/">Песков отреагировал на обсуждение в соцсетях бренда куртки Путина</a>,
#  <a href="/rubrics/russia/">Все материалы</a>,
#  <a href="/rubrics/world/">Мир</a>,
#  <a data-partslug="text" href="/articles/2018/08/28/somalia/"><img alt="" class="g-picture" height="64" src="https://icdn.lenta.ru/images/2018/08/24/13/20180824135704912/tabloid_92e416e04f752dde39bd63bca9869ee5.jpg" style="max-width: 96px; width: 96px; height: 64px;" width="96"/><span class="b-tabloid__headline">Нефтяной ад</span><div class="rightcol">Как живется в самой опасной стране Африки</div></a>,
#  <a href="/news/2018/08/28/ne_ostanavlivaisja/">США отказались прекращать военные учения с Южной Кореей ради Северной</a>,
#  <a href="/news/2018/08/28/razvedka/">США провели разведку возле Сирии</a>,
#  <a href="/news/2018/08/28/may_dance/">Мэй станцевала с африканцами и вызвала неодобрение британцев<svg class="svg-icons__video-play"><use xlink:href="#ui-topic_play"></use></svg></a>,
#  <a href="/news/2018/08/28/conflict/">В НАТО увидели подготовку России к масштабным военным действиям</a>,
#  <a data-partslug="text" href="/articles/2018/08/26/china_us/"><img alt="" class="g-picture" height="64" src="https://icdn.lenta.ru/images/2018/08/23/19/20180823190200001/tabloid_98a0858ca4776413c6b913b02a3e8858.jpg" style="max-width: 96px; width: 96px; height: 64px;" width="96"/><span class="b-tabloid__headline">Берег смерти</span><div class="rightcol">Америка и Китай едва не устроили ядерную войну. Всех спас Советский Союз</div></a>,
#  <a data-partslug="text" href="/articles/2018/08/26/rip_mccain/"><img alt="Джон Маккейн" class="g-picture" height="64" src="https://icdn.lenta.ru/images/2018/08/24/19/20180824193907557/tabloid_a72df1b7503edcf42179ed20c72cb893.jpg" style="max-width: 96px; width: 96px; height: 64px;" width="96"/><span class="b-tabloid__headline">Злейший друг</span><div class="rightcol">Сенатор Маккейн воевал с Россией и любил Америку. Его боялся даже Трамп</div></a>,
#  <a href="/rubrics/world/">Все материалы</a>,
#  <a href="/rubrics/ussr/">Бывший СССР</a>,
#  <a data-partslug="text" href="/photo/2018/08/25/ukrparad/"><img alt="" class="g-picture" height="64" src="https://icdn.lenta.ru/images/2018/08/24/18/20180824181208831/tabloid_ea34574ab1600fd3db7290449da4a4f3.jpg" style="max-width: 96px; width: 96px; height: 64px;" width="96"/><span class="b-tabloid__headline">Вся украинская рать</span><div class="rightcol">В Киеве провели самый грандиозный парад за всю историю. Почти никто не пострадал</div></a>,
#  <a href="/news/2018/08/28/ilovaisk/">Киев подсчитал потери российских военных в боях под Иловайском в 2014 году</a>,
#  <a data-partslug="text" href="/articles/2018/08/22/kvartet/"><img alt="Александр Лукашенко" class="g-picture" height="64" src="https://icdn.lenta.ru/images/2018/08/21/20/20180821204056594/tabloid_2b585c981717a5696a0a4472b4a4d025.jpg" style="max-width: 96px; width: 96px; height: 64px;" width="96"/><span class="b-tabloid__headline">«Крысы, мыши и прочая наркота»</span><div class="rightcol">Лукашенко снова разогнал министров. Станут ли белорусы жить лучше?</div></a>,
#  <a href="/news/2018/08/28/bah/">«Король Instagram» приехал в Нагорный Карабах и устроил пальбу<svg class="svg-icons__video-play"><use xlink:href="#ui-topic_play"></use></svg></a>,
#  <a href="/news/2018/08/28/nagrubil/">Порошенко нагрубил журналисту и попал на видео<svg class="svg-icons__video-play"><use xlink:href="#ui-topic_play"></use></svg></a>,
#  <a href="/news/2018/08/28/poxoroni/">Неоязычники пришли на похороны бойца АТО и учинили мордобой ради топора в гробу<svg class="svg-icons__video-play"><use xlink:href="#ui-topic_play"></use></svg></a>,
#  <a data-partslug="text" href="/articles/2018/08/18/saakyan/"><img alt="" class="g-picture" height="64" src="https://icdn.lenta.ru/images/2018/08/16/10/20180816103545752/tabloid_7c178604141a8dae7a8553be9f2499a6.jpg" style="max-width: 96px; width: 96px; height: 64px;" width="96"/><span class="b-tabloid__headline">«У власти была своя крыша»</span><div class="rightcol">Он хочет овладеть Карабахом и стать новым Пашиняном</div></a>,
#  <a href="/rubrics/ussr/">Все материалы</a>,
#  <a href="/rubrics/economics/">Экономика</a>,
#  <a data-partslug="text" href="/articles/2018/08/26/beer_and_weed/"><img alt="" class="g-picture" height="64" src="https://icdn.lenta.ru/images/2018/08/24/14/20180824144622572/tabloid_550e1612aba8615e7999b1a91deca82e.jpg" style="max-width: 96px; width: 96px; height: 64px;" width="96"/><span class="b-tabloid__headline">Дурь в кармане</span><div class="rightcol">Пиво соединят с марихуаной. Это будет стоить миллиарды</div></a>,
#  <a data-partslug="text" href="/articles/2018/08/17/irkutsk/"><img alt="" class="g-picture" height="64" src="https://icdn.lenta.ru/images/2018/08/17/19/20180817191844533/tabloid_5d40b1e209960d1b991310be5fd7e71f.jpg" style="max-width: 96px; width: 96px; height: 64px;" width="96"/><span class="b-tabloid__headline">Бюджет как оружие</span><div class="rightcol">От политических игр иркутского губернатора-коммуниста страдает весь регион</div></a>,
#  <a data-partslug="text" href="/articles/2018/08/24/greece/"><img alt="" class="g-picture" height="64" src="https://icdn.lenta.ru/images/2018/08/22/17/20180822172823675/tabloid_9e0a3ccb941409cb51a08a33794148f2.jpg" style="max-width: 96px; width: 96px; height: 64px;" width="96"/><span class="b-tabloid__headline">Дальше сами</span><div class="rightcol">Эта страна обманывала весь мир и жила в долг. Пришла пора платить</div></a>,
#  <a href="/news/2018/08/28/shmalio/">Названы главные условия для роста российской экономики</a>,
#  <a href="/news/2018/08/28/avitogold/">На Avito выставили золотые месторождения</a>,
#  <a href="/news/2018/08/28/morgritual/">Власти взялись за похоронный бизнес</a>,
#  <a href="/news/2018/08/28/plan_benzin/">Раскрыт план по сдерживанию цен на бензин</a>,
#  <a href="/rubrics/economics/">Все материалы</a>,
#  <a href="/rubrics/forces/">Силовые структуры</a>,
#  <a data-partslug="text" href="/articles/2018/08/28/escort/"><img alt="" class="g-picture" height="64" src="https://icdn.lenta.ru/images/2018/08/27/18/20180827180025128/tabloid_d31855cda939adefec0fd7a2363c2eb1.jpg" style="max-width: 96px; width: 96px; height: 64px;" width="96"/><span class="b-tabloid__headline">«Это будет клеймо по жизни»</span><div class="rightcol">Российские девушки продают себя за миллионы. Жажда роскоши приводит их в тюрьму</div></a>,
#  <a data-partslug="text" href="/articles/2018/08/27/orel/"><img alt="" class="g-picture" height="64" src="https://icdn.lenta.ru/images/2018/08/24/12/20180824124153495/tabloid_7f3c2f1e67a26a18edf1303c9031fcda.jpg" style="max-width: 96px; width: 96px; height: 64px;" width="96"/><span class="b-tabloid__headline">Служительница тьмы</span><div class="rightcol">Россиянка жестоко убила парня, ее боится весь город. Почему она на свободе?</div></a>,
#  <a data-partslug="text" href="/themes/2018/06/13/vvz/"><img alt="" class="g-picture" height="64" src="https://icdn.lenta.ru/images/2018/06/13/11/20180613114632255/tabloid_6e5edf2801bfc794ca310350b9579039.jpg" style="max-width: 96px; width: 96px; height: 64px;" width="96"/><span class="b-tabloid__headline">Доля воровская</span><div class="rightcol">Воры в законе: кто они? Спецпроект «Ленты.ру»</div></a>,
#  <a href="/news/2018/08/28/ataka/">Установлено число напавших на воинский эшелон в Забайкалье</a>,
#  <a href="/news/2018/08/28/doctor/">Анестезиолог изнасиловал россиянку под наркозом и пошел под суд</a>,
#  <a href="/news/2018/08/28/banda/">В Петербурге объявилась банда подростков-подражателей АУЕ</a>,
#  <a href="/news/2018/08/28/shalmuev/">Следователи узнали имя платившего пойманному в Италии российскому сенатору</a>,
#  <a href="/rubrics/forces/">Все материалы</a>,
#  <a href="/rubrics/science/">Наука и техника</a>,
#  <a data-partslug="text" href="/articles/2018/08/27/science/"><img alt="" class="g-picture" height="64" src="https://icdn.lenta.ru/images/2018/08/26/13/20180826132923382/tabloid_1f8d0cd69b1d3b83ff6f9e8485d6278e.jpg" style="max-width: 96px; width: 96px; height: 64px;" width="96"/><span class="b-tabloid__headline">Взяли за душу</span><div class="rightcol">У человека в теле нашли новый орган. Для чего он нужен?</div></a>,
#  <a data-partslug="text" href="/articles/2018/08/26/kiwami3/"><img alt="" class="g-picture" height="64" src="https://icdn.lenta.ru/images/2018/08/23/15/20180823152559216/tabloid_a10eb0252cee0c38bc45397221f7dbda.jpg" style="max-width: 96px; width: 96px; height: 64px;" width="96"/><span class="b-tabloid__headline">Каникулы дракона</span><div class="rightcol">Чем занимаются японские бандиты во время отпуска: Yakuza Kiwami 2</div></a>,
#  <a href="/news/2018/08/28/vacation/">Названа неожиданная польза частого отпуска</a>,
#  <a href="/news/2018/08/28/diet/">Здоровый образ жизни оказался смертельно опасным</a>,
#  <a href="/news/2018/08/28/armata/">В России ответили на критику «Арматы»</a>,
#  <a href="/news/2018/08/28/tu22m3m/">Раскрыта миссия первого Ту-22М3М</a>,
#  <a href="/news/2018/08/28/sun/">Замечен загадочный феномен на Солнце</a>,
#  <a href="/rubrics/science/">Все материалы</a>,
#  <a href="/rubrics/sport/">Спорт</a>,
#  <a data-partslug="text" href="/articles/2018/08/28/internet_war/"><img alt="Хабиб Нурмагомедов" class="g-picture" height="64" src="https://icdn.lenta.ru/images/2018/08/27/19/20180827192041707/tabloid_4acf6601e95aae6beccd018f895e0e4a.jpg" style="max-width: 96px; width: 96px; height: 64px;" width="96"/><span class="b-tabloid__headline">«Хабиб даст ответ на все»</span><div class="rightcol">Макгрегор и Нурмагомедов дерутся в интернете. Реальный бой все ближе</div></a>,
#  <a href="/news/2018/08/28/salah/">Салах пожаловался на пребывание в Чечне во время чемпионата мира</a>,
#  <a href="/news/2018/08/28/roma/">Тренер обрадовался решающему голу и сломал себе руку<svg class="svg-icons__video-play"><use xlink:href="#ui-topic_play"></use></svg></a>,
#  <a href="/news/2018/08/28/cristiano_bicycle/">УЕФА назвал лучший гол сезона<svg class="svg-icons__video-play"><use xlink:href="#ui-topic_play"></use></svg></a>,
#  <a href="/news/2018/08/28/kuzmina_slo/">Названа причина перехода сестры Шипулина в сборную Словакии</a>,
#  <a href="/news/2018/08/28/samara_arena/">«Самара Арене» вернули свет</a>,
#  <a href="/news/2018/08/28/stadium/">На стадионе чемпионата мира отключили электричество за долги</a>,
#  <a href="/rubrics/sport/">Все материалы</a>,
#  <a href="/rubrics/culture/">Культура</a>,
#  <a data-partslug="text" href="/articles/2018/08/28/gusvansant/"><img alt="" class="g-picture" height="64" src="https://icdn.lenta.ru/images/2018/08/27/20/20180827205510006/tabloid_739b89b50fd74d1a9e52bd890d0752f9.jpg" style="max-width: 96px; width: 96px; height: 64px;" width="96"/><span class="b-tabloid__headline">«Смерть Робина Уильямса открыла фильму дорогу»</span><div class="rightcol">Гас Ван Сэнт о своем байопике скандального художника Джона Каллахана</div></a>,
#  <a data-partslug="text" href="/articles/2018/08/21/signal/"><img alt="" class="g-picture" height="64" src="https://icdn.lenta.ru/images/2018/08/20/18/20180820185142746/tabloid_8e33edfc1997215853f3085527956bd3.jpg" style="max-width: 96px; width: 96px; height: 64px;" width="96"/><span class="b-tabloid__headline">«Секс в палатке должен быть быстрым и немножко грязным»</span><div class="rightcol">Что творилось на огромном рейве в трех часах от Москвы</div></a>,
#  <a data-partslug="text" href="/articles/2018/08/27/kvadrat/"><img alt="" class="g-picture" height="64" src="https://icdn.lenta.ru/images/2018/08/26/18/20180826184100704/tabloid_9283666b21ec1b0ca38736834954b437.jpg" style="max-width: 96px; width: 96px; height: 64px;" width="96"/><span class="b-tabloid__headline">«Эпоха вертухаевых внучат»</span><div class="rightcol">Владимир Сорокин о том, как советское прошлое привело к российскому настоящему</div></a>,
#  <a href="/news/2018/08/28/loshad/">Киану Ривз возбудил поклонников фотографией на коне</a>,
#  <a href="/news/2018/08/28/grob/">Тело величайшей певицы в истории положили в золотой гроб и выставили в музее</a>,
#  <a href="/news/2018/08/28/preem/">Лимонов назвал преемника Путина и предрек России «много крови»</a>,
#  <a href="/news/2018/08/28/kreen/">Умер актер из «Убойной силы»</a>,
#  <a href="/rubrics/culture/">Все материалы</a>,
#  <a href="/rubrics/media/">Интернет и СМИ</a>,
#  <a data-partslug="text" href="/articles/2018/08/27/buzova/"><img alt="Ольга Бузова" class="g-picture" height="64" src="https://icdn.lenta.ru/images/2018/08/26/23/20180826231442216/tabloid_4d1cd96e5aed2d03ab539ffea4e34526.jpg" style="max-width: 96px; width: 96px; height: 64px;" width="96"/><span class="b-tabloid__headline">«Для меня ты не мужик. Ты тупо пятно, которое несет фигню»</span><div class="rightcol">Бузова открывает мир других мужчин на телевидении. Они бьются за нее, как львы</div></a>,
#  <a href="/news/2018/08/28/ya/">Роскомнадзор пригрозил «Яндексу» блокировкой</a>,
#  <a href="/news/2018/08/28/vnov_prodoljaetsya_boy/">Дуров объяснился за сотрудничество Telegram со спецслужбами</a>,
#  <a data-partslug="text" href="/articles/2018/08/10/depression/"><img alt="" class="g-picture" height="64" src="https://icdn.lenta.ru/images/2018/08/09/17/20180809173710437/tabloid_45775c29c6da8c44353c119568769e10.jpg" style="max-width: 96px; width: 96px; height: 64px;" width="96"/><span class="b-tabloid__headline">«Я жду, когда окончательно сломаюсь»</span><div class="rightcol">Они добились славы и денег, но отказались от всего ради счастья</div></a>,
#  <a data-partslug="text" href="/articles/2018/08/24/job/"><img alt="" class="g-picture" height="64" src="https://icdn.lenta.ru/images/2018/08/23/15/20180823155219980/tabloid_3007750bd71bbd310198c5c465167451.jpg" style="max-width: 96px; width: 96px; height: 64px;" width="96"/><span class="b-tabloid__headline">«Лучше уйти. Дальше будет только хуже»</span><div class="rightcol">Блогер походил по собеседованиям со скрытой камерой и разоблачил работодателей</div></a>,
#  <a href="/news/2018/08/28/telegram/">Telegram стал частично доступен в России</a>,
#  <a href="/news/2018/08/28/telega/">Telegram согласился выдавать спецслужбам данные пользователей</a>,
#  <a href="/rubrics/media/">Все материалы</a>,
#  <a href="/rubrics/style/">Ценности</a>,
#  <a data-partslug="text" href="/articles/2018/08/27/streetfoodrevolution/"><img alt="" class="g-picture" height="64" src="https://icdn.lenta.ru/images/2018/08/25/00/20180825005839924/tabloid_5320249d060e41505f7ee3739586c1c1.jpg" style="max-width: 96px; width: 96px; height: 64px;" width="96"/><span class="b-tabloid__headline">Дети ларька</span><div class="rightcol">Шаурма, бургеры и фалафель: кто научил москвичей вкусно питаться</div></a>,
#  <a data-partslug="text" href="/articles/2018/08/14/old_fashioned_women/"><img alt="Лиля Брик" class="g-picture" height="64" src="https://icdn.lenta.ru/images/2018/08/13/20/20180813200003778/tabloid_0716b50d3ef8ff8efc0d223e527f25df.jpg" style="max-width: 96px; width: 96px; height: 64px;" width="96"/><span class="b-tabloid__headline">Новые богини</span><div class="rightcol">Самые сексуальные, богатые и опасные женщины эпохи гангстеров и джаза</div></a>,
#  <a data-partslug="text" href="/articles/2018/08/26/papasha_ho/"><img alt="Ho Chi Minh (1890-1969), Vietnamese Communist revolutionary and Dictator, Prime Minister (1946-1955) and President (1945-1969) of the Democratic Republic of Vietnam (North Vietnam). " class="g-picture" height="64" src="https://icdn.lenta.ru/images/2018/08/24/14/20180824141205231/tabloid_83a7f4ddb94fde2c52783c3fae401d8a.jpg" style="max-width: 96px; width: 96px; height: 64px;" width="96"/><span class="b-tabloid__headline">Дядюшка Хо</span><div class="rightcol">Женщины, сигареты и войны величайшего вьетнамца планеты</div></a>,
#  <a href="/news/2018/08/28/billiondollars/">Раскрыт ежечасный заработок кандидатки в самые молодые миллиардерши</a>,
#  <a href="/news/2018/08/28/navelshape/">Раскрыто значение формы пупка</a>,
#  <a href="/news/2018/08/27/fivepieces/">Перечислены самые необходимые мужчине вещи</a>,
#  <a href="/news/2018/08/28/redblazer/">Меган Маркл стала примером для масс-маркета</a>,
#  <a href="/rubrics/style/">Все материалы</a>,
#  <a href="/rubrics/travel/">Путешествия</a>,
#  <a data-partslug="text" href="/articles/2018/08/25/berlin/"><img alt="Отдыхающие на набережной Шпрее в жаркий летний день. Берлин, Германия" class="g-picture" height="64" src="https://icdn.lenta.ru/images/2018/08/17/17/20180817173728687/tabloid_01d414e5f7f6c9023b90f1c11d636737.jpg" style="max-width: 96px; width: 96px; height: 64px;" width="96"/><span class="b-tabloid__headline">На Берлин!</span><div class="rightcol">Россияне обязательно должны побывать в столице Германии. И вот почему</div></a>,
#  <a data-partslug="text" href="/articles/2018/08/24/tindertravel/"><img alt="В горах часто можно встретить стада овец, которые не дают проехать ни на каком транспорте" class="g-picture" height="64" src="https://icdn.lenta.ru/images/2018/08/23/20/20180823200516640/tabloid_397d7b089e718743bb9212f3ba960722.jpg" style="max-width: 96px; width: 96px; height: 64px;" width="96"/><span class="b-tabloid__headline">«Привет, красавица! Пообщаемся?»</span><div class="rightcol">Чем заканчиваются свидания с незнакомцами на Кавказе</div></a>,
#  <a data-partslug="photo" href="/photo/2018/08/18/whilewaiting/"><img alt="Sunflower Garden inside of the Singapore Changi Airport" class="g-picture" height="64" src="https://icdn.lenta.ru/images/2018/08/17/15/20180817153520516/tabloid_2fef69156b607fa474a6b4d23feb0b39.jpg" style="max-width: 96px; width: 96px; height: 64px;" width="96"/><span class="b-tabloid__headline">Страсти небесные</span><div class="rightcol">Бани, каток и райские сады: куда сходить в лучших аэропортах мира</div></a>,
#  <a href="/news/2018/08/28/nodelay/">Авиакомпании увеличили время полета ради выгоды</a>,
#  <a href="/news/2018/08/28/chinafear/">Два лайнера едва не разбились из-за столкновения с неопознанным самолетом</a>,
#  <a href="/news/2018/08/27/zvezdavshoke/">Сергей Зверев устроил истерику в аэропорту и попал на видео<svg class="svg-icons__video-play"><use xlink:href="#ui-topic_play"></use></svg></a>,
#  <a href="/news/2018/08/28/wistlebaby/">Самый большой авиалайнер развернули на полпути из-за свиста</a>,
#  <a href="/rubrics/travel/">Все материалы</a>,
#  <a href="/rubrics/life/">Из жизни</a>,
#  <a data-partslug="text" href="/articles/2018/08/28/iceland/"><img alt="" class="g-picture" height="64" src="https://icdn.lenta.ru/images/2018/08/27/16/20180827163506717/tabloid_4f0b6547d55c0475376e0ba2ae6ff7a4.jpg" style="max-width: 96px; width: 96px; height: 64px;" width="96"/><span class="b-tabloid__headline">«Полиция развозит пьяных по домам»</span><div class="rightcol">История москвички, переехавшей в Исландию</div></a>,
#  <a data-partslug="null" href="/articles/2018/08/22/dogchempionat/"><img alt="" class="g-picture" height="64" src="https://icdn.lenta.ru/images/2018/08/22/13/20180822132214098/tabloid_8120f4323e6681340d1838381ec094df.jpg" style="max-width: 96px; width: 96px; height: 64px;" width="96"/><span class="b-tabloid__headline">У собак есть свои секреты</span><div class="rightcol">На чемпионате мира для собак россияне завоевали три призовых места из десяти </div></a>,
#  <a data-partslug="photo" href="/photo/2018/08/25/chicken/"><img alt="" class="g-picture" height="64" src="https://icdn.lenta.ru/images/2018/08/22/15/20180822151545971/tabloid_2215a4bc139ca28458d6e4af81cacf5f.jpg" style="max-width: 96px; width: 96px; height: 64px;" width="96"/><span class="b-tabloid__headline">Кость в горле</span><div class="rightcol">Они поглощают куриные крылышки тоннами. Этого лучше не видеть</div></a>,
#  <a href="/news/2018/08/28/dolphin/">Озабоченный дельфин утомил пловцов приставаниями</a>,
#  <a href="/news/2018/08/28/kaprizulya/">Британец 17 лет ел только наггетсы и картошку из-за редкого заболевания</a>,
#  <a href="/news/2018/08/27/vegans/">Веганский фестиваль отменили после угроз охотников и фермеров</a>,
#  <a href="/news/2018/08/27/hippo/">Бегемот убил спасшегося от крокодила рыбака</a>,
#  <a href="/rubrics/life/">Все материалы</a>,
#  <a class="b-tabloid__item-rubric b-tabloid__item-rubric_logo-motor" href="/rubrics/motor/" target="_blank"><svg class="b-tabloid__item-rubric-icon"><use xlink:href="#ui-logo-motor"></use></svg></a>,
#  <a class="b-link-external" href="http://motor.ru" target="_blank"><svg class="b-link-external-icon"><use xlink:href="#ui-link-external"></use></svg></a>,
#  <a data-partslug="null" href="https://motor.ru/selector/exoffroadpart2.htm/?utm_source=from_lenta" target="_blank"><img alt="" class="g-picture" height="64" src="https://icdn.lenta.ru/images/2018/08/28/10/20180828101832326/tabloid_285ef35482387e95c48b9aaf64fbf353.jpg" style="max-width: 96px; width: 96px; height: 64px;" width="96"/><span class="b-tabloid__headline">Внедорожники, ставшие кроссоверами II</span><div class="rightcol">Шесть машин, сменивших внедорожное прошлое на кроссоверное настоящее. Часть вторая</div></a>,
#  <a data-partslug="null" href="https://motor.ru/selector/scandalads.htm/?utm_source=from_lenta" target="_blank"><img alt="" class="g-picture" height="64" src="https://icdn.lenta.ru/images/2018/08/28/10/20180828101723222/tabloid_0be4b6645ba0db6fd70ca6463ec5dd04.jpg" style="max-width: 96px; width: 96px; height: 64px;" width="96"/><span class="b-tabloid__headline">Скандальная реклама автомобилей</span><div class="rightcol">Сексизм, черный юмор и насмешки над конкурентами в рекламе машин</div></a>,
#  <a data-partslug="null" href="https://motor.ru/selector/porsche-rally.htm/?utm_source=from_lenta" target="_blank"><img alt="" class="g-picture" height="64" src="https://icdn.lenta.ru/images/2018/08/27/09/20180827095919847/tabloid_2592133330878a39061cde87dac1f516.jpg" style="max-width: 96px; width: 96px; height: 64px;" width="96"/><span class="b-tabloid__headline">Porsche в грязи</span><div class="rightcol">Спорткары, которые обгоняли на грунтовке внедорожники: Porsche возвращается в ралли</div></a>,
#  <a data-partslug="null" href="https://motor.ru/selector/osi-silver-fox.htm/?utm_source=from_lenta" target="_blank"><img alt="" class="g-picture" height="64" src="https://icdn.lenta.ru/images/2018/08/27/10/20180827100410140/tabloid_cd4f64b0b86b8b28279f7c7d706d7283.jpg" style="max-width: 96px; width: 96px; height: 64px;" width="96"/><span class="b-tabloid__headline">Провал машины-катамарана</span><div class="rightcol">Экстраординарная звезда Ле-Мана, которая так и не взошла</div></a>,
#  <a href="https://motor.ru/news/renault-concept-28-08-2018.htm?utm_source=from_lenta" target="_blank">«Renault из будущего» сфотографировали на улице Варшавы</a>,
#  <a href="https://motor.ru/news/nissanjuke2-28-08-2018.htm?utm_source=from_lenta" target="_blank">Следующий Nissan Juke останется странным</a>,
#  <a href="https://motor.ru/news/kate-28-08-2018.htm?utm_source=from_lenta" target="_blank">Сборку коробки для седана проекта «Кортеж» показали на видео</a>,
#  <a href="/rubrics/motor/">Все материалы</a>,
#  <a class="b-tabloid__item-rubric b-tabloid__item-rubric_logo-dom" href="/rubrics/realty/" target="_blank"><svg class="b-tabloid__item-rubric-icon"><use xlink:href="#ui-logo-dom"></use></svg></a>,
#  <a class="b-link-external" href="http://dom.lenta.ru" target="_blank"><svg class="b-link-external-icon"><use xlink:href="#ui-link-external"></use></svg></a>,
#  <a data-partslug="null" href="http://dom.lenta.ru/articles/2018/08/28/bridgevsrealty/?utm_source=from_lenta" target="_blank"><img alt="" class="g-picture" height="64" src="https://icdn.lenta.ru/images/2018/08/27/20/20180827204123613/tabloid_fcd46fa7b626efe0dc6c00133b199d82.jpg" style="max-width: 96px; width: 96px; height: 64px;" width="96"/><span class="b-tabloid__headline">Под мостом</span><div class="rightcol">Сколько стоит жилье в Крыму</div></a>,
#  <a data-partslug="text" href="http://dom.lenta.ru/articles/2018/08/20/tfuderevnya/?utm_source=from_lenta" target="_blank"><img alt="" class="g-picture" height="64" src="https://icdn.lenta.ru/images/2018/08/19/19/20180819192346824/tabloid_d76d7c87bfe18c8a1e874bdaba8f4a61.jpg" style="max-width: 96px; width: 96px; height: 64px;" width="96"/><span class="b-tabloid__headline">«Вечером лучше вообще не выходить на улицу»</span><div class="rightcol">Москвичка переехала на дачу. Ее жизнь превратилась в ад</div></a>,
#  <a data-partslug="photo" href="http://dom.lenta.ru/photo/2018/08/25/bookstores/?utm_source=from_lenta" target="_blank"><img alt="El Ateneo Grand Splendid, Buenos Aires" class="g-picture" height="64" src="https://icdn.lenta.ru/images/2018/08/23/15/20180823151751255/tabloid_6801f42b971cbd08622715ff9ee0806c.jpg" style="max-width: 96px; width: 96px; height: 64px;" width="96"/><span class="b-tabloid__headline">Бумажный рай</span><div class="rightcol">В этих магазинах хочется жить. Только посмотрите</div></a>,
#  <a href="http://dom.lenta.ru/news/2018/08/27/mortgagerates/?utm_source=from_lenta" target="_blank">Россиянам пообещали снижение ставок по ипотеке</a>,
#  <a href="http://dom.lenta.ru/news/2018/08/27/robbed/?utm_source=from_lenta" target="_blank">Квартиру известного коллекционера обворовали в Москве</a>,
#  <a href="http://dom.lenta.ru/news/2018/08/25/hellhouse/?utm_source=from_lenta" target="_blank">Шокировавший известного блогера дом решили снести</a>,
#  <a href="http://dom.lenta.ru/news/2018/08/27/stinkycities/?utm_source=from_lenta" target="_blank">Названы самые вонючие города России</a>,
#  <a href="/rubrics/realty/">Все материалы</a>,
#  <a class="b-footer__mobile-link" href="https://m.lenta.ru/2018/08/25/"><svg class="b-footer__mobile-icon"><use xlink:href="#ui-phone"></use></svg><span class="b-footer__mobile-label">Мобильная версия</span></a>,
#  <a href="/info/">Редакция</a>,
#  <a href="/info/posts/sales">Реклама</a>,
#  <a href="/parts/pressreleases/">Пресс-релизы</a>,
#  <a href="mailto:it@lenta-co.ru">Техподдержка</a>,
#  <a href="/specprojects/">Спецпроекты</a>,
#  <a href="http://rambler-co.ru/jobs" target="_blank">Вакансии</a>,
#  <a href="/rss">RSS</a>]

# %% [markdown]
# Кажется, это опять немного не то, что нам нужно. Мы получили все ссылки, находящиеся на боковом меню, ссылки на события сегодняшнего дня и другие ненужные нам вещи. <br>
# Смотрим в содержимое html-страницы и обращаем внимание, что все интересные нам ссылки оформлены как заголовки третьего уровня - &lt;h3&gt;. Извлечем все такие фрагменты, а потом извлечем собственно адреса, помеченные атрибутом href тега &lt;a&gt;.

# %%
h3s=BeautifulSoup(requests.get("http://lenta.ru/2018/08/25/").text, "html5lib").find_all("h3")
links=["http://lenta.ru"+l.find_all("a")[0]["href"] for l in h3s]
print(links)
# Out:
# ['http://lenta.ru/articles/2018/08/25/shishkan/', 'http://lenta.ru/photo/2018/08/25/chicken/', 'http://lenta.ru/photo/2018/08/25/ukrparad/', 'http://lenta.ru/articles/2018/08/25/dzyuba/', 'http://lenta.ru/articles/2018/08/25/berlin/', 'http://lenta.ru/photo/2018/08/25/school_children/', 'http://lenta.ru/brief/2018/08/25/slepakovvsshnur/', 'http://lenta.ru/news/2018/08/25/potomu/', 'http://lenta.ru/news/2018/08/25/rastvorova/', 'http://lenta.ru/news/2018/08/25/razvedka/', 'http://lenta.ru/news/2018/08/25/poezd/', 'http://lenta.ru/news/2018/08/25/bolton/', 'http://lenta.ru/news/2018/08/25/nur/', 'http://lenta.ru/news/2018/08/25/firetornado/', 'http://lenta.ru/news/2018/08/25/drake/', 'http://lenta.ru/news/2018/08/25/merkel/', 'http://lenta.ru/news/2018/08/25/serena/', 'http://lenta.ru/news/2018/08/25/python/', 'http://lenta.ru/news/2018/08/25/ukrain/', 'http://lenta.ru/news/2018/08/25/vsetaki_pustili/', 'http://lenta.ru/news/2018/08/25/boycott_curtis/', 'http://lenta.ru/news/2018/08/25/twitterrr/', 'http://lenta.ru/news/2018/08/25/milliardy/', 'http://lenta.ru/news/2018/08/25/otrajenie/', 'http://lenta.ru/news/2018/08/25/dope_ioc/', 'http://lenta.ru/news/2018/08/25/edro/', 'http://lenta.ru/news/2018/08/25/galaktika_v_opasnosti/', 'http://lenta.ru/news/2018/08/25/seady_steady/', 'http://lenta.ru/news/2018/08/25/nurma/', 'http://lenta.ru/news/2018/08/25/chetvero_smelyh/', 'http://lenta.ru/news/2018/08/25/binoculars/', 'http://lenta.ru/news/2018/08/25/rybakii/', 'http://lenta.ru/news/2018/08/25/ron_boost/', 'http://lenta.ru/news/2018/08/25/hvastun/', 'http://lenta.ru/news/2018/08/25/hi/', 'http://lenta.ru/news/2018/08/25/revenko/', 'http://lenta.ru/news/2018/08/25/body/', 'http://lenta.ru/news/2018/08/25/terrorr/', 'http://lenta.ru/news/2018/08/25/joejoe_rip/', 'http://lenta.ru/news/2018/08/25/ibra/', 'http://lenta.ru/news/2018/08/25/bird/', 'http://lenta.ru/news/2018/08/25/kneissl/', 'http://lenta.ru/news/2018/08/25/sledcom/', 'http://lenta.ru/news/2018/08/25/pregnancy/', 'http://lenta.ru/news/2018/08/25/new_arena/', 'http://lenta.ru/news/2018/08/25/edro_meme/', 'http://lenta.ru/news/2018/08/25/plita/', 'http://lenta.ru/news/2018/08/25/mcgregor_caucas/', 'http://lenta.ru/news/2018/08/25/batut/', 'http://lenta.ru/news/2018/08/25/vegan/', 'http://lenta.ru/news/2018/08/25/spartak_dinamo/', 'http://lenta.ru/news/2018/08/25/train/', 'http://lenta.ru/news/2018/08/25/ronaldo_blocks/', 'http://lenta.ru/news/2018/08/25/kiev/', 'http://lenta.ru/news/2018/08/25/fcb/', 'http://lenta.ru/news/2018/08/25/kyle/', 'http://lenta.ru/news/2018/08/25/provacation/']

# %% [markdown]
# Если теперь написать функцию, которая будет перебирать все адреса и получать из них тексты новостей, то мы получим все новости за определенные сутки. Но это мы сделаем чть позже, а пока просто оформим код загрузки статьи в виде функции.

# %%
# Загрузка статьи по URL.
def getOneLentaArticle(url):
    """ getLentaArticle gets the body of an article from Lenta.ru"""
    # Получает текст страницы.
    resp=requests.get(url)
    # Загружаем текст в объект типа BeautifulSoup.
    bs=BeautifulSoup(resp.text, "html5lib") 
    # Получаем заголовок статьи.
    aTitle=bs.h1.text.replace("\xa0", " ")
    # Получаем текст статьи.
    anArticle=BeautifulSoup(" ".join([p.text for p in bs.find_all("p")]), "html5lib").get_text().replace("\xa0", " ")
    return aTitle, anArticle

# %% [markdown]
# Разобравшись с базовыми библиотеками, перейдем теперь к обработке собственно текстов. Самостоятельно это можно сделать прочитав одну из двух книг: <a href='https://miem.hse.ru/clschool/the_book'>поновее</a> и <a href='http://clschool.miem.edu.ru/uploads/swfupload/files/011a69a6f0c3a9c6291d6d375f12aa27e349cb67.pdf'>постарше</a> (в старой хорошо разобраны классификация и кластеризация, в новой - тематическое моделирование и рядом лежит видео лекций).<br>
# Для обработки текста проводится два этапа анализа: <b>графематический</b> (выделение предложений и слов) и <b>морфологический</b> (определение начальной формы слова, его части речи и грамматических параметров). Этап синтаксического анализа мы разбирать не будем, так как его информация требуется не всегда.<br>
# Задачей графематического анализа является разделение текста на составные части - врезки, абзацы, предложения, слова. В таких задачах как машинный перевод, точность данного этапа может существенно влиять на точность получаемых результатов. Например, точка, используемая для сокращений, может быть воспринята как конец предложения, что полность разорвет его семантику.<br>
# Но в некоторых задачах (например нашей) используется подход <b>"мешок слов"</b> - текст воспринимается как неупорядоченное множество слов, для которых можно просто посчитать их частотность в тексте. Данный подход проще реализовать, для него не нужно делать выделение составных частей текста, а необходимо только выделить слова.  Именно этот подход мы и будем использовать.<br>

# %%
import pymorphy2 # Морфологический анализатор.
from collections import Counter # Не считать же частоты самим.
import math # Корень квадратный.

# %% [markdown]
# Задачей морфологического анализа является определение начальной формы слова, его части речи и грамматических параметров. В некоторых случаях от слова требуется только начальная форма, в других - только начальная форма и часть речи.<br>
# Существует два больших подхода к морфологическому анализу: <b>стемминг</b> и <b>поиск по словарю</b>. Для проведения стемминга оставляется справочник всех окончаний для данного языка. Для пришедшего слова проверяется его окончание и по нему делается прогноз начальной формы и части речи.<br>
# Например, мы создаем справочник, в котором записываем все окончания прилагательных: <i>-ому, -ему, -ой, -ая, -ий, -ый, ...</i> Теперь все слова, которые имеют такое окончание будут считаться прилагаельными: <i>синий, циклический, красного, больному</i>. Заодно прилагательными будут считаться причастия (<i>делающий, строившему</i>) и местоимения (<i>мой, твой, твоему</i>). Также не понятно что делать со словами, имеющими пустое окончание. Отдельную проблему составляют такие слова, как <i>стекло, больной, вина</i>, которые могут разбираться несколькими вариантами (это явление называется <b>омонимией</b>). Помимо этого, стеммер может просто откусывать окончания, оставляя лишь псевдооснову.<br>
# Большинство проблем здесь решается, но точность работы бессловарных стеммеров находится на уровне 80%. Чтобы повысить точность испольуют морфологический анализ со словарем. Разработчики составляют словарь слов, встретившихся в текстах (<a href="http://opencorpora.org/dict.php">здесь</a> можно найти пример такого словаря). Теперь каждое слово будет искаться в словаре и не предсказываться, а выдаваться точно. Для слов, отсутствующих в словаре, может применяться предсказание, пообное работе стеммера.<br>
# Посмотрим как работает словарная морфология на примере системы pymorphy2.

# %%
morph=pymorphy2.MorphAnalyzer() # Создает объект морфоанализатора и загружет словарь.
wordform=morph.parse('стекло')  # Проведем анализ слова "стекло"...
print(wordform)                 # ... и посмотрим на результат.
# Out:
# [Parse(word='стекло', tag=OpencorporaTag('NOUN,inan,neut sing,nomn'), normal_form='стекло', score=0.75, methods_stack=((<DictionaryAnalyzer>, 'стекло', 545, 0),)), Parse(word='стекло', tag=OpencorporaTag('NOUN,inan,neut sing,accs'), normal_form='стекло', score=0.1875, methods_stack=((<DictionaryAnalyzer>, 'стекло', 545, 3),)), Parse(word='стекло', tag=OpencorporaTag('VERB,perf,intr neut,sing,past,indc'), normal_form='стечь', score=0.0625, methods_stack=((<DictionaryAnalyzer>, 'стекло', 968, 3),))]

# %% [markdown]
# Как видно из вывода, слово "стекло" может быть неодушевленным существительным среднего рода, единственного числа, именительного падежа <i>tag=OpencorporaTag('NOUN,inan,neut sing,nomn')</i>, аналогично, но в винительном падеже (<i>'NOUN,inan,neut sing,accs'</i>), и глаголом <i>'VERB,perf,intr neut,sing,past,indc'</i>. При этом в первой форме оно встречается в 75% случаев (<i>score=0.75</i>), во второй в 18,75% случаев (<i>score=0.1875</i>), а как глагол - лишь в 6,25% (<i>score=0.0625</i>). Самым простым видом борьбы с омонимией является выбор нулевого элемента из списка, возвращенного морфологическим анализом. Такой подход дает около 90% точности при выборе начальной формы и до 80% если мы обращаем внимание на грамматические параметры.<br><br>
# Вместо Pymorphy можно использовать PyMystem. Его плюсом является тот факт, что он сам проводит графематический анализ и снимает омонимию. Используя функцию lemmatize можно получить набор начальных форм слов. Используя функцию analyze можно получить полную информацию о словах.

# %%
import pymystem3
mystem=pymystem3.Mystem()

# %%
print(mystem.lemmatize('эти типы стали есть в цеху'))
print(mystem.analyze('эти типы стали есть в цеху'))
# Out:
# ['этот', ' ', 'тип', ' ', 'становиться', ' ', 'есть', ' ', 'в', ' ', 'цех', '\n']
# [{'analysis': [{'lex': 'этот', 'wt': 1, 'gr': 'APRO=(им,мн|вин,мн,неод)'}], 'text': 'эти'}, {'text': ' '}, {'analysis': [{'lex': 'тип', 'wt': 0.8700298642, 'gr': 'S,муж,неод=(вин,мн|им,мн)'}], 'text': 'типы'}, {'text': ' '}, {'analysis': [{'lex': 'становиться', 'wt': 0.9821285244, 'gr': 'V,нп=прош,мн,изъяв,сов'}], 'text': 'стали'}, {'text': ' '}, {'analysis': [{'lex': 'есть', 'wt': 0.0492236161, 'gr': 'V,несов,пе=инф'}], 'text': 'есть'}, {'text': ' '}, {'analysis': [{'lex': 'в', 'wt': 0.9999917878, 'gr': 'PR='}], 'text': 'в'}, {'text': ' '}, {'analysis': [{'lex': 'цех', 'wt': 1, 'gr': 'S,муж,неод=(дат,ед|местн,ед)'}], 'text': 'цеху'}, {'text': '\n'}]

# %% [markdown]
# Но мы будем использовать pymorphy, так как он немного пошустрее.<br><br>

# %%
art_title, art_text = getOneLentaArticle("https://lenta.ru/news/2018/02/15/greben/")
print(art_title, "\n-----\n", art_text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-1191224d34ef> in <module>()
# ----> 1 art_title, art_text = getOneLentaArticle("https://lenta.ru/news/2018/02/15/greben/")
#       2 print(art_title, "\n-----\n", art_text)
#
# NameError: name 'getOneLentaArticle' is not defined

# %% [markdown]
# Для новостной заметки можно составить ее словарь, а также посчитать частоты всех слов. В итоге мы получим представление текста в виде вектора. В этом векторе координаты будут называться по соответствующим словам, а смещение по данной координате будет показывать частота. <br>
# При составлении словаря будем учитывать только значимые слова - существительные, прилагательные и глаголы. Помимо этого предусмотрим возможность учитывать часть речи слова, прибавляя ее у начальной форме.<br>
# Для разделения текста на слова используем простейший алгоритм: слово - это последовательность букв русского алфавита среди которых может попадаться дефис.

# %%
posConv={'ADJF':'_ADJ','NOUN':'_NOUN','VERB':'_VERB'}
meaningfullPoSes=['ADJF', 'NOUN', 'VERB']

def getArticleDictionary(text, needPos=None):
    words=[a[0] for a in re.findall("([А-ЯЁа-яё]+(-[А-ЯЁа-яё]+)*)", text)]
    reswords=[]

    for w in words:
        wordform=morph.parse(w)[0]
        if wordform.tag.POS in meaningfullPoSes:
            if needPos!=None:
                reswords.append(wordform.normal_form+posConv[wordform.tag.POS])
            else:
                reswords.append(wordform.normal_form)
            
    return Counter(reswords)

stat1=getArticleDictionary(art_text, True)
print(stat1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-a2272ac7f7c8> in <module>()
#      16     return Counter(reswords)
#      17
# ---> 18 stat1=getArticleDictionary(art_text, True)
#      19 print(stat1)
#      20
#
# NameError: name 'art_text' is not defined

# %% [markdown]
# Более правильным методом является использование CountVectorizer из sklearn.feature_extraction.text. При помощи функции <i>fit_transform</i> можно получить разреженное представление матрицы частот слов. Основная проблема состоит в том, что индексы в матрице представляют собой индексы в словаре переданных текстов. Сам словарь хранится в свойстве <i>vocabulary_</i> и умеет возвращать индекс по слову (но не наоборот).

# %%
from sklearn.feature_extraction.text import CountVectorizer

counter=CountVectorizer()
# Просим посчитать частоты слов.
res=counter.fit_transform([art_text])
# Разреженное представление счетчика.
print(res[0][0,:10])
# Можно получить индекс по слову, ...
print(counter.vocabulary_.get('фильм'))
# ... но не наоборот.
print(counter.vocabulary_.get(110))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-f4dd8cc21ab8> in <module>()
#       3 counter=CountVectorizer()
#       4 # Просим посчитать частоты слов.
# ----> 5 res=counter.fit_transform([art_text])
#       6 # Разреженное представление счетчика.
#       7 print(res[0][0,:10])
#
# NameError: name 'art_text' is not defined

# %% [markdown]
# Более того, CountVectorizer просто выделяет подстроки и ничего не знает про морфологию (ее можно правильно прикрутить, но это хлопотное занятие). Зато он умеет выделять n-граммы (n слов идущих подряд (или даже букв)). Помимо этого, можно попросить выдать все подстроки, создав анализатор. И можно сказать как выделять подстроки при помощи регулярного выражения.

# %%
lyrics="""У тебя в кармане
Два мелка и волшебный камень.
Ты волшебный камень
На Восьмое марта подаришь маме.
А с высокой крыши
Все на свете слышно.
Кто-то хитрый и большой
Наблюдает за тобой."""

# При помощи ngram_range=(1,2) говорим, что хотим извлекать слова и пары слов.
# token_pattern показывает регулярное выражение, которому должны соответствовать слова.
counter12=CountVectorizer(ngram_range=(1,2))#, token_pattern=r'[А-Яа-яЁё]+\-[А-Яа-яЁё]+|[А-Яа-яЁё]+')
# Проводим анализ, получаем список найденных n-грамм.
analyze = counter12.build_analyzer()
print(analyze(lyrics))
# Считаем частоты, видим, что слова не приводились к начальной форме.
res=counter12.fit_transform([lyrics])
print(counter12.vocabulary_.get('маме'))
print(counter12.vocabulary_.get('мама'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-253599a3bfe5> in <module>()
#      10 # При помощи ngram_range=(1,2) говорим, что хотим извлекать слова и пары слов.
#      11 # token_pattern показывает регулярное выражение, которому должны соответствовать слова.
# ---> 12 counter12=CountVectorizer(ngram_range=(1,2))#, token_pattern=r'[А-Яа-яЁё]+\-[А-Яа-яЁё]+|[А-Яа-яЁё]+')
#      13 # Проводим анализ, получаем список найденных n-грамм.
#      14 analyze = counter12.build_analyzer()
#
# NameError: name 'CountVectorizer' is not defined

# %% [markdown]
# Давайте попробуем прикрутить к нему морфологию, но сделаем это немного по-своему. Разобьем строку на слова, проведем их морфологический анализ, возьмем начальные формы и снова склеим в строку, которую отдадим в CountVectorizer. И сделаем тоже самое, только для значимых слов. Как видно из результата, текст перестал быть про "тебя", а стал о чем-то немного другом.

# %%
def getMeaningfullWords(text):
    words=[]
    tokens=re.findall('[А-Яа-яЁё]+\-[А-Яа-яЁё]+|[А-Яа-яЁё]+', text)
    for t in tokens:
        pv=morph.parse(t)
        for p in pv:
            if p.tag.POS in ['ADJF', 'NOUN', 'VERB']:
                words.append(p.normal_form)
                break
    return words

c=[' '.join(getMeaningfullWords(lyrics))]
c2=[' '.join([morph.parse(r)[0].normal_form for r in re.findall('[А-Яа-яЁё]+\-[А-Яа-яЁё]+|[А-Яа-яЁё]+', lyrics)])]

lemmaCounter=CountVectorizer(ngram_range=(1,2), token_pattern=r'[А-Яа-яЁё]+\-[А-Яа-яЁё]+|[А-Яа-яЁё]+')

analyze = lemmaCounter.build_analyzer()
res1=analyze(c[0])
res2=lemmaCounter.fit_transform(c)
print({w:res2[0][0,lemmaCounter.vocabulary_[w]] for w in lemmaCounter.vocabulary_ if res2[0][0,lemmaCounter.vocabulary_[w]]>1})
print("---")
res1=analyze(c2[0])
res2=lemmaCounter.fit_transform(c2)
print({w:res2[0][0,lemmaCounter.vocabulary_[w]] for w in lemmaCounter.vocabulary_ if res2[0][0,lemmaCounter.vocabulary_[w]]>1})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-e37935aefa19> in <module>()
#      10     return words
#      11
# ---> 12 c=[' '.join(getMeaningfullWords(lyrics))]
#      13 c2=[' '.join([morph.parse(r)[0].normal_form for r in re.findall('[А-Яа-яЁё]+\-[А-Яа-яЁё]+|[А-Яа-яЁё]+', lyrics)])]
#      14
#
# NameError: name 'lyrics' is not defined

# %% [markdown]
# Обратите внимание на слово "исполняющий". В исходном тексте его не было.<br>
# Оно появилось так как одним из (не самых вероятных) значений слова "и" является сокращение от "исполняющий". Так как для каждого слова я пытался найти его значение как значимой части речи, союз был отброшен, а вот прилагательное осталось.

# %% [markdown]
# Но это лирика, а в новостях получается не так чувствительно. Более того, на одно из первых мест выходит устойчивое словосочетание - "домашний арест".

# %%
c=[' '.join(getMeaningfullWords(art_text))]
c2=[' '.join([morph.parse(r)[0].normal_form for r in re.findall('[А-Яа-яЁё]+\-[А-Яа-яЁё]+|[А-Яа-яЁё]+', art_text)])]

lemmaCounter=CountVectorizer(ngram_range=(1,2), token_pattern=r'[А-Яа-яЁё]+\-[А-Яа-яЁё]+|[А-Яа-яЁё]+')

analyze = lemmaCounter.build_analyzer()
res1=analyze(c[0])
res2=lemmaCounter.fit_transform(c)
print({w:res2[0][0,lemmaCounter.vocabulary_[w]] for w in lemmaCounter.vocabulary_ if res2[0][0,lemmaCounter.vocabulary_[w]]>1})
print("---")
res1=analyze(c2[0])
res2=lemmaCounter.fit_transform(c2)
print({w:res2[0][0,lemmaCounter.vocabulary_[w]] for w in lemmaCounter.vocabulary_ if res2[0][0,lemmaCounter.vocabulary_[w]]>1})
# Out:
# {'группа': 2, 'гребенщик': 2, 'фильм': 3, 'серебренников': 3, 'лето': 3, 'его': 3, 'век': 6, 'февраль': 2, 'сценарий': 3, 'под': 2, 'домашний': 2, 'арест': 2, 'иза': 2, 'науменко': 2, 'зверь': 2, 'год': 2, 'под домашний': 2, 'домашний арест': 2}
# ---
# {'группа': 2, 'гребенщик': 2, 'не': 3, 'фильм': 3, 'серебренников': 3, 'лето': 2, 'он': 3, 'в': 6, 'февраль': 2, 'сценарий': 3, 'под': 2, 'домашний': 2, 'арест': 2, 'из': 2, 'науменко': 2, 'зверь': 2, 'год': 2, 'под домашний': 2, 'домашний арест': 2}

# %% [markdown]
# Но нам необходимо искать новости, которые интересны пользователю.<p>
# Для определения меры сходства двух статей теперь может использоваться косинусная мера сходства, рассчитываемая по следующей формуле: $cos(a,b)=\frac{\sum{a_i * b_i}}{\sqrt {\sum{a_i^2}*\sum{b_i^2}}}$.<br>
# Вообще-то, использовать стандартную функцию рассчета косинусной меры сходства из <a href="http://scikit-learn.org/stable/modules/generated/sklearn.metrics.pairwise.cosine_similarity.html">sklearn</a> было бы быстрее. Но в данной задаче нам бы пришлось сводить все словари в один, чтобы на одних и тех же местах в векторе были частоты одних и тех же слов. Чтобы избежать подобной работы, напишем собственную функцию рассчета косинусного расстояния, работающую с разреженными векторами в виде питоновских словарей.

# %%
def cosineSimilarity(a, b):
    if len(a.keys())==0 or len(b.keys())==0:
        return 0
    sumab=sum([a[na]*b[na] for na in a.keys() if na in b.keys()])
    suma2=sum([a[na]*a[na] for na in a.keys()])
    sumb2=sum([b[nb]*b[nb] for nb in b.keys()])
    return sumab/math.sqrt(suma2*sumb2)

# %% [markdown]
# Кстати, вы обратили внимание на красивую формулу в маркдауне выше? Здесь можно использовать html и LaTex для красивого оформления. Например, тег &lt;b&gt;позволяет сделать текст <b>полужирным</b>.

# %% [markdown]
# Посчитаем значение косинусной меры для разных статей.

# %%
stat2=getArticleDictionary(getOneLentaArticle("https://lenta.ru/news/2018/02/15/pengilly_domoi/")[1], True)
stat3=getArticleDictionary(getOneLentaArticle("https://lenta.ru/news/2018/02/15/tar_mor/")[1], True)
stat4=getArticleDictionary(getOneLentaArticle("https://lenta.ru/news/2018/02/15/olympmovies/")[1], True)

print(cosineSimilarity(stat1, stat2))
print(cosineSimilarity(stat1, stat3))
print(cosineSimilarity(stat2, stat3))
print(cosineSimilarity(stat2, stat4))
print(cosineSimilarity(stat3, stat4))
# Out:
# 0.0800246267513914
# 0.0
# 0.09061004703659373
# 0.09777979218062152
# 0.08519427513705972

# %%
# training - my function 5/15 пересечение словрей делим на объединение словарей
def closeSimilarity(a, b):
    if len(a.keys())==0 or len(b.keys())==0:
        return 0
    sumab=sum([a[na]*b[na] for na in a.keys() if na in b.keys()])
    suma2=sum([a[na]*a[na] for na in a.keys()])
    sumb2=sum([b[nb]*b[nb] for nb in b.keys()])
#    return sumab/(suma2+sumb2)
    return len(set(a.keys()&set(b.keys())))/len(set(a.keys()|set(b.keys())))
# return len(set(a.keys()&set(b.keys())))/len(set(a.keys))
# return len(set(a.keys()&set(b.keys())))/len(set(a.keys()|set(b.keys())))

# %%
print(closeSimilarity(stat1, stat2))
print(closeSimilarity(stat1, stat3))
print(closeSimilarity(stat2, stat3))
print(closeSimilarity(stat2, stat4))
print(closeSimilarity(stat3, stat4))
# Out:
# 0.0392156862745098
# 0.0
# 0.056
# 0.04216867469879518
# 0.050724637681159424

# %% [markdown]
# Получилось, на самом деле, так себе - статьи очень слабо походят друг на друга. Но может быть потом выйдет лучше.<br>

# %% [markdown]
# <font color="red" size="6">А теперь немного поупражняемся.</font><br>
# Напишите функцию, которая ищет процент пересечения словарей у двух статей с применением MyStem.

# %% [markdown]
# Оформим теперь весь необходимый код как класс, который будет загружать новости с сайта, сохранять их в файл и читать из предварительно сохраненного файла.<br>
# Класс - это тип, определенный пользователем (программистом). Класс содержит в себе как данные, так и функции, которые работают с этими данными.<br>
# Так как это тип, то можно создавать переменные этого типа. Каждая переменная будет хранить и обрабатывать свой набор данных.

# %%
class getNewsPaper:
        
    # Конструктор - вызывается при создании объекта и инициализирует его.
    def __init__(self):
        self.articles=[]     # Загруженные статьи.
        self.titles=[]       # Заголовки статей.
        self.dictionaries=[] # Словари для каждой из статей.
        # Создаем и загружаем морфологический словарь.
        self.morph=pymorphy2.MorphAnalyzer()

    # Загрузка статьи по URL.
    def getLentaArticle(self, url):
        """ getLentaArticle gets the body of an article from Lenta.ru"""
        # Получает текст страницы.
        resp=requests.get(url)
        # Загружаем текст в объект типа BeautifulSoup.
        bs=BeautifulSoup(resp.text, "html5lib") 
        # Получаем заголовок статьи.
        self.titles.append(bs.h1.text.replace("\xa0", " "))
        # Получаем текст статьи.
        self.articles.append(BeautifulSoup(" ".join([p.text for p in bs.find_all("p")]), "html5lib").get_text().replace("\xa0", " "))

    # Загрузка всех статей за один день.
    def getLentaDay(self, url):
        """ Gets all URLs for a given day and gets all texts. """
        try:
            # Грузим страницу со списком всех статей.
            day = requests.get(url) 
            # Получаем фрагменты с нужными нам адресами статей.
            h3s=BeautifulSoup(day.text, "html5lib").find_all("h3")
            # Получаем все адреса на статьи за день.
            links=["http://lenta.ru"+l.find_all("a")[0]["href"] for l in h3s]
            # Загружаем статьи.
            for l in links:
                self.getLentaArticle(l)
        except:
            pass

    # Загрузка всех статей за несколько дней.
    def getLentaPeriod(self, start, finish):
        curdate=start
        while curdate<=finish:
            print(curdate.strftime('%Y/%m/%d')) # Just in case.
            # Список статей грузится с вот такого адреса.
            self.getLentaDay('https://lenta.ru/news/'+curdate.strftime('%Y/%m/%d'))
            curdate+=datetime.timedelta(days=1)

    # Потроение вектора для статьи.
    posConv={'ADJF':'_ADJ','NOUN':'_NOUN','VERB':'_VERB'}
    def getArticleDictionary(self, text, needPos=None):
        words=[a[0] for a in re.findall("([А-ЯЁа-яё]+(-[А-ЯЁа-яё]+)*)", text)]
        reswords=[]
    
        for w in words:
            wordform=self.morph.parse(w)[0]
            try:
                if wordform.tag.POS in ['ADJF', 'NOUN', 'VERB']:
                    if needPos!=None:
                        reswords.append(wordform.normal_form+self.posConv[wordform.tag.POS])
                    else:
                        reswords.append(wordform.normal_form)
            except:
                pass
            
        stat=Counter(reswords)
#        stat={a: stat[a] for a in stat.keys() if stat[a]>1}
        return stat

    # Посчитаем вектора для всех статей.
    def calcArticleDictionaries(self, needPos=None):
        self.dictionaries=[]
        for a in self.articles:
            self.dictionaries.append(self.getArticleDictionary(a, needPos))
            
    # Сохраняем статьи в файл.
    def saveArticles(self, filename):
        """ Saves all articles to a file with a filename. """
        newsfile=open(filename, "w")
        for art in self.articles:
            newsfile.write('\n=====\n'+art)
        newsfile.close()

    # Читаем статьи из файла.
    def loadArticles(self, filename):
        """ Loads and replaces all articles from a file with a filename. """
        newsfile=open(filename, encoding="utf-8")
        text=newsfile.read()
        self.articles=text.split('\n=====\n')[1:]
        for a in self.articles:
            self.titles.append(a.split('\n-----\n')[0])
        newsfile.close()

    # Для удобства - поиск статьи по ее заголовку.
    def findNewsByTitle(self, title):
        if title in self.titles:
            return self.titles.index(title)
        else:
            return -1

def cosineSimilarity(a, b):
    if len(a.keys())==0 or len(b.keys())==0:
        return 0
    sumab=sum([a[na]*b[na] for na in a.keys() if na in b.keys()])
    suma2=sum([a[na]*a[na] for na in a.keys()])
    sumb2=sum([b[nb]*b[nb] for nb in b.keys()])
    return sumab/math.sqrt(suma2*sumb2)

# %% [markdown]
# Загрузим статьи.<br>
# <b>!!! Настоятельно рекомендую использовать ячейку с загрузкой статей из файла !!!</b>

# %%
# Загрузка статей за заданный период.
# !!! Это рабоатет довольно долго, пользуйтесь сохраненными данными!!!
lenta=getNewsPaper()
lenta.getLentaPeriod(datetime.date(2018, 2, 1), datetime.date(2018, 2, 14))
lenta.saveArticles("lenta2018.txt")
#lenta.loadArticles("lenta2018.txt")
lenta.calcArticleDictionaries()

# %%
import datetime

# %%
lenta=getNewsPaper()
lenta.loadArticles("lenta2018-2.txt")
lenta.calcArticleDictionaries()

# %% [markdown]
# Из чистого любопытства попробуем найти статью, наиболее похожую на данную.

# %%
# Конечно же, правильнее делать это через np.argmax().
i1 = 0
maxCos, maxpos = -1, -1
for i in range(len(lenta.articles)):
    if i != i1:
        c = cosineSimilarity(lenta.dictionaries[i1], lenta.dictionaries[i])
        if c>maxCos:
            maxCos, maxpos = c, i
print(lenta.articles[i1].split('\n-----\n')[0])
print(lenta.articles[maxpos].split('\n-----\n')[0])
print(maxCos, maxpos)
# Out:
# Раскрыто происхождение новейшей украинской крылатой ракеты
# Россия поставила Украине оружие «сдерживания агрессора»
# 0.6522716186492549 516

# %% [markdown]
# Сходство между статьями достаточно велико. Есть большие шансы за то, что они об одном и том же.<br><br>
# Теперь попробуем решить основную задачу.<br>
# Пользователь выбирает несколько статей на интересующую его тематику. Пусть это будут олимпиада и выборы.

# %%
likesport=['Власти США обвинили МОК и ФИФА в коррупции', 'Пробирки WADA для допинг-проб оказались бракованными', 'Пожизненно отстраненных российских спортсменов оправдали', 'В Кремле порадовались за оправданных российских спортсменов', 'Россия вернется на первое место Олимпиады-2014', 'МОК разочаровало оправдание российских олимпийцев', 'Мутко загрустил после оправдания российских спортсменов', 'Оправданный призер Сочи-2014 призвал «добить ситуацию» с МОК', 'Путин предостерег от эйфории после оправдания российских олимпийцев', 'Родченков не смог вразумительно ответить на вопросы суда', 'Оправданный россиянин позлорадствовал над делившими медали Игр-2014 иностранцами', 'В CAS отказались считать оправданных россиян невиновными', 'Адвокат Родченкова заговорил о смерти чистого спорта после оправдания россиян', 'Американская скелетонистка сочла россиян ушедшими от законного наказания']
likeelect=['Социологи подсчитали планирующих проголосовать на выборах-2018', 'Собчак пообещала дать Трампу пару советов', 'На выборы президента России пойдут почти 80 процентов избирателей', 'Песков вспомнил предупреждение и отказался комментировать поездку Собчак в США', 'Собчак съездила на завтрак с Трампом и разочаровалась', 'Грудинин уступил в популярности КПРФ', 'Собчак потребовала признать незаконной регистрацию Путина на выборах', 'У Грудинина обнаружили два не до конца закрытых счета в Швейцарии и Австрии', 'Грудинин раскрыл историю происхождения дома в Испании', 'Путина зарегистрировали кандидатом в президенты', 'В Кремле отреагировали на слухи о голосовании Путина в Севастополе', 'Коммунистов вновь обвинили в незаконной агитации за Грудинина', 'ЦИК выявила обман со стороны Грудинина', 'Грудинин ответил на претензии ЦИК', 'Жириновский захотел сбросить ядерную бомбу на резиденцию Порошенко']

# %% [markdown]
# Теперь объединим все выбранные тексты в один и посчитаем ветор для него. Сделаем это два раза для выбранных тематик.

# %%
sporttext=' '.join([lenta.articles[lenta.findNewsByTitle(art)] for art in likesport])
sportdict=lenta.getArticleDictionary(sporttext)
electtext=' '.join([lenta.articles[lenta.findNewsByTitle(art)] for art in likeelect])
electdict=lenta.getArticleDictionary(electtext)
print(sportdict)
#print(electdict)
# Out:
# Counter({'спортсмен': 47, 'игра': 35, 'олимпиада': 34, 'российский': 30, 'быть': 29, 'суд': 29, 'мокнуть': 28, 'россия': 25, 'пожизненный': 24, 'антидопинговый': 24, 'олимпийский': 22, 'сочи': 22, 'решение': 21, 'нарушение': 16, 'правило': 16, 'февраль': 16, 'результат': 16, 'россиянин': 15, 'материал': 14, 'тема': 14, 'апелляция': 14, 'международный': 13, 'комитет': 13, 'спортивный': 13, 'арбитражный': 13, 'отстранение': 13, 'участие': 13, 'победа': 11, 'год': 10, 'который': 10, 'вернуть': 10, 'медаль': 10, 'удовлетворить': 9, 'родченков': 9, 'вопрос': 8, 'заявить': 8, 'слово': 8, 'весь': 8, 'февраляотстоять': 8, 'сочисо': 8, 'снять': 8, 'четверг': 7, 'аннулировать': 7, 'атлет': 7, 'зачёт': 7, 'тот': 7, 'оправдание': 7, 'агентство': 6, 'этот': 6, 'александр': 6, 'виновный': 6, 'награда': 6, 'первое': 6, 'место': 6, 'медальный': 6, 'ряд': 6, 'приводить': 6, 'спорт': 6, 'дисквалификация': 5, 'глава': 5, 'всемирный': 5, 'лыжник': 5, 'дать': 5, 'наш': 5, 'чистый': 5, 'сша': 4, 'расследование': 4, 'сообщать': 4, 'чемпионат': 4, 'мир': 4, 'дело': 4, 'показание': 4, 'январь': 4, 'пробирка': 4, 'контейнер': 4, 'пхенчхан': 4, 'ноябрь': 4, 'допинг': 4, 'сообщить': 4, 'возможность': 4, 'представитель': 4, 'санкция': 4, 'декабрь': 4, 'флаг': 4, 'ситуация': 4, 'информатор': 4, 'признать': 4, 'отстранить': 4, 'президент': 4, 'мочь': 4, 'говорить': 4, 'борьба': 4, 'золотой': 4, 'прокомментировать': 4, 'свой': 4, 'смочь': 4, 'имя': 4, 'адвокат': 4, 'крюков': 4, 'федерация': 3, 'компания': 3, 'право': 3, 'допинга-проба': 3, 'оказаться': 3, 'демченко': 3, 'ничья': 3, 'победароссия': 3, 'поехать': 3, 'гимн': 3, 'развал': 3, 'ссср': 3, 'заменить': 3, 'григорий': 3, 'потерять': 3, 'песок': 3, 'подчеркнуть': 3, 'страна': 3, 'государство': 3, 'сборная': 3, 'легкова': 3, 'третьяков': 3, 'серебряный': 3, 'число': 3, 'новость': 3, 'комиссия': 3, 'денис': 3, 'освальд': 3, 'конец': 3, 'позволить': 3, 'один': 3, 'время': 3, 'скелетонистка': 3, 'наказание': 3, 'юлендёр': 3, 'власть': 2, 'фифа': 2, 'коррупция': 2, 'футбол': 2, 'ассоциация': 2, 'легкоатлетический': 2, 'информация': 2, 'возможный': 2, 'выбор': 2, 'рамка': 2, 'получить': 2, 'сентябрь': 2, 'го': 2, 'бывший': 2, 'диак': 2, 'рекомендовать': 2, 'использование': 2, 'образец': 2, 'сообщаться': 2, 'сайт': 2, 'организация': 2, 'чемпион': 2, 'стать': 2, 'специальный': 2, 'ранний': 2, 'модель': 2, 'генеральный': 2, 'заявлять': 2, 'оправдать': 2, 'войти': 2, 'скелетонист': 2, 'евгений': 2, 'белов': 2, 'конькобежка': 2, 'ольга': 2, 'фаткулина': 2, 'альберт': 2, 'запрет': 2, 'видеосвязь': 2, 'лицо': 2, 'рука': 2, 'кремль': 2, 'порадоваться': 2, 'пресс-секретарь': 2, 'удовлетворение': 2, 'подтверждать': 2, 'действие': 2, 'лента': 2, 'сказать': 2, 'поддержка': 2, 'отстаивание': 2, 'отметить': 2, 'другой': 2, 'день': 2, 'такой': 2, 'проявление': 2, 'связь': 2, 'вернуться': 2, 'лыжный': 2, 'гонка': 2, 'самый': 2, 'сборный': 2, 'бронзовый': 2, 'олимпиец': 2, 'намерение': 2, 'федеральный': 2, 'швейцария': 2, 'большинство': 2, 'политика': 2, 'горечь': 2, 'слушание': 2, 'сомневаться': 2, 'чистота': 2, 'добавить': 2, 'восстановить': 2, 'призёр': 2, 'призвать': 2, 'чей': 2, 'отменить': 2, 'ребята': 2, 'заниматься': 2, 'руководство': 2, 'путин': 2, 'эйфория': 2, 'уважение': 2, 'сторона': 2, 'сам': 2, 'допрос': 2, 'чёткий': 2, 'ответ': 2, 'арбитр': 2, 'знак': 2, 'анна': 2, 'козьменко': 2, 'выступать': 2, 'иностранец': 2, 'узнать': 2, 'сочинский': 2, 'невиновный': 2, 'участник': 2, 'смерть': 2, 'уолден': 2, 'американский': 2, 'счесть': 2, 'верить': 2, 'никитин': 2, 'обвинить': 1, 'министерство': 1, 'юстиция': 1, 'начать': 1, 'факт': 1, 'иааф': 1, 'национальный': 1, 'издание': 1, 'минюст': 1, 'заинтересоваться': 1, 'отмывание': 1, 'деньга': 1, 'вымогательство': 1, 'мошенничество': 1, 'махинация': 1, 'хозяин': 1, 'лёгкий': 1, 'атлетика': 1, 'доха': 1, 'юджин': 1, 'рассчитывать': 1, 'свидетельский': 1, 'документ': 1, 'запись': 1, 'финансовый': 1, 'транзакция': 1, 'балвалентин': 1, 'балахничев': 1, 'касаться': 1, 'помочь' ...

# %% [markdown]
# А теперь отберем все статьи, косинусная мера которых превышает некоторый порог.

# %%
thrs=0.4
thre=0.5
cosess=[lenta.articles[i].split('\n-----\n')[0] for i in range(len(lenta.dictionaries)) if cosineSimilarity(sportdict, lenta.dictionaries[i])>thrs]
print(cosess)
cosese=[lenta.articles[i].split('\n-----\n')[0] for i in range(len(lenta.dictionaries)) if cosineSimilarity(electdict, lenta.dictionaries[i])>thre]
print(cosese)
# Out:
# ['Пожизненно отстраненных российских спортсменов оправдали', 'В Кремле порадовались за оправданных российских спортсменов', 'Россия вернется на первое место Олимпиады-2014', 'МОК разочаровало оправдание российских олимпийцев', 'Мутко загрустил после оправдания российских спортсменов', 'Олимпиада в Пхенчхане побила рекорд по презервативам', 'Оправданный призер Сочи-2014 призвал «добить ситуацию» с МОК', 'Путин предостерег от эйфории после оправдания российских олимпийцев', 'Родченков не смог вразумительно ответить на вопросы суда', 'Оправданный россиянин позлорадствовал над делившими медали Игр-2014 иностранцами', 'В CAS отказались считать оправданных россиян невиновными', 'Адвокат Родченкова заговорил о смерти чистого спорта после оправдания россиян', 'Американская скелетонистка сочла россиян ушедшими от законного наказания', 'Глава USADA почуял вонь российской атаки на чистый спорт', 'После оправдания российских спортсменов Макларена назвали идиотом', 'МОК посчитал оправдание российских спортсменов «торжеством обманщиков и воров»', 'Федерацию бобслея России обвинили в нежелании пускать спортсменов на Олимпиаду', 'Названы условия продолжения борьбы МОК против россиян', 'Четырехкратный олимпийский чемпион встал на сторону россиян и пристыдил МОК', 'МОК подумает над приглашением на Олимпиаду оправданных россиян', 'Оправданным россиянам запретили участвовать в Олимпиаде', 'МОК обозначил сроки по решению о допуске оправданных россиян на Олимпиаду', 'В секретной базе найдены сотни аномальных допинг-проб', 'Назван знаменосец россиян на открытии Олимпиады', 'Комиссия МОК отказалась пустить на Олимпиаду оправданных CAS россиян', 'WADA сорвало тренировку сборной России по хоккею в Пхенчхане', 'Глава МОК рассказал о процедуре допуска оправданных россиян на Олимпиаду', 'Песков прокомментировал отказ МОК пустить на Олимпиаду оправданных россиян', 'Шесть российских сборных отказались от участия в церемонии открытия Олимпиады', 'МОК сделает из россиян пример нетерпимости к допингу', 'Лыжники присоединились к отказавшимся от церемонии открытия Олимпиады россиянам', 'Медведев пристыдил МОК', 'Президент МОК объяснил нежелание приглашать на Игры оправданных россиян', 'Немцы порадовались решению не пускать оправданных россиян на Олимпиаду', 'МОК уличил очередных российских спортсменов в употреблении допинга', 'Российские спортсмены продолжили борьбу с МОК', 'Раскрыты условия снятия запрета на российский флаг на Олимпиаде', 'Россиянам спрогнозировали девять медалей на Олимпиаде-2018', 'В Европе нашлась новая допинг-система', 'Серебряный призер Сочи пригрозила сунуть медаль между булок желающим ее забрать', 'Российские спортсмены пропустят Олимпиаду из-за затянувшегося суда', 'Американскую спортсменку разозлило оправдание российских олимпийцев', 'Названы условия появления российского флага на закрытии Игр', 'Немецкий биатлонист сравнил оправдание российских олимпийцев с плевком в лицо', 'Хакеры раскрыли канадский заговор против российского спорта', 'Российские керлингисты уступили сборной США в дебютной игре Олимпиады-2018', 'Российские олимпийцы пожаловались на слежку со стороны иностранной прессы', 'Российские олимпийцы подверглись дискриминации со стороны канадцев', 'CAS отказался рассматривать апелляции отстраненных от Олимпиады россиян', 'Российские болельщики осадили штаб-квартиру WADA', 'Потерявший шансы попасть на Олимпиаду Кулижников прокомментировал решение CAS', 'Бренды и чиновники отказались от индивидуальности ради российских спортсменов', 'Трехкратная чемпионка мира выступила против наказания невиновных россиян', 'Российские олимпийцы смогут носить шапку с триколором', 'Отстраненные россияне лишились последнего шанса поехать на Олимпиаду', 'WADA возрадовалось решению CAS о недопуске россиян к Олимпиаде', 'МОК поддержал решение не допустить российских спортсменов на Олимпиаду', 'Адвокат Родченкова поблагодарил бога за недопуск россиян на Олимпиаду', 'Мутко назвал причины недопуска россиян на Олимпиаду', 'Кремль прокомментировал решени ...
# ['Социологи подсчитали планирующих проголосовать на выборах-2018', 'У Грудинина обнаружили два не до конца закрытых счета в Швейцарии и Австрии', 'Грудинин раскрыл историю происхождения дома в Испании', 'Путина зарегистрировали кандидатом в президенты', 'В Кремле отреагировали на слухи о голосовании Путина в Севастополе', 'На выборы президента России пойдут почти 80 процентов избирателей', 'Песков вспомнил предупреждение и отказался комментировать поездку Собчак в США', 'Собчак съездила на завтрак с Трампом и разочаровалась', 'Коммунистов вновь обвинили в незаконной агитации за Грудинина', 'Грудинин ответил на претензии ЦИК', 'Грудинин уступил в популярности КПРФ', 'Собчак потребовала признать незаконной регистрацию Путина на выборах']

# %% [markdown]
# Для проверки загрузим новости за какой-то другой день.

# %%
lenta_new=getNewsPaper()
#lenta_new.getLentaPeriod(datetime.date(2018, 2, 15), datetime.date(2018, 2, 15))
#lenta_new.saveArticles("lenta20180215.txt")
lenta_new.loadArticles("lenta20180215.txt")
lenta_new.calcArticleDictionaries()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-fa30e558178d> in <module>()
#       2 #lenta_new.getLentaPeriod(datetime.date(2018, 2, 15), datetime.date(2018, 2, 15))
#       3 #lenta_new.saveArticles("lenta20180215.txt")
# ----> 4 lenta_new.loadArticles("lenta20180215.txt")
#       5 lenta_new.calcArticleDictionaries()
#
# <ipython-input-2-8c3cc5fe8dbb> in loadArticles(self, filename)
#      84     def loadArticles(self, filename):
#      85         """ Loads and replaces all articles from a file with a filename. """
# ---> 86         newsfile=open(filename, encoding="utf-8")
#      87         text=newsfile.read()
#      88         self.articles=text.split('\n=====\n')[1:]
#
# FileNotFoundError: [Errno 2] No such file or directory: 'lenta20180215.txt'

# %% [markdown]
# А теперь проверим какие новости будут находиться.

# %%
thrs_new = 0.3
thre_new = 0.3
cosess_new = [lenta_new.articles[i].split('\n-----\n')[0] for i in range(len(lenta_new.dictionaries)) if cosineSimilarity(sportdict, lenta_new.dictionaries[i])>thrs_new]
print(cosess_new)
cosese_new = [lenta_new.articles[i].split('\n-----\n')[0] for i in range(len(lenta_new.dictionaries)) if cosineSimilarity(electdict, lenta_new.dictionaries[i])>thre_new]
print(cosese_new)
# Out:
# ['Российский сноубордист сломал ногу на Олимпиаде', 'Российскую лыжницу затравили на Олимпиаде']
# ['Кремль опроверг информацию о засекречивании данных по россиянам в Сирии', 'Порошенко раскрыл детали разговора с Путиным', 'Грудинин оговорился о финансовых махинациях', 'Прогнозируемую явку на выборах президента сочли высокой']

# %% [markdown]
# Как видно, метод нуждается в более точном подборе и корректировке параметров.

# %% [markdown]
# Вместо того, чтобы выделять самые частотные слова в одной статье, мы можем использовать несколько иную логику. Слово является важным, если оно часто встречается в <b>данной</b> статье. Однако если это слово часто встречается во всех статьях, скорее всего оно не значимо (так ведут себя предлоги, союзы, слова, относящиеся к особенностям авторского или принятого в данной области стиля). То есть наиболее характерными для данного документа будут слова и словосочетания, которые встречаются часто в данном докумемнте, но в малом количестве документов.<br>
# Для выделения таких слов будем использовать TfidfVectorizer, работающий по формуле tf/idf, где tf - term frequency, а idf - inverted document frequency. То есть в простейшем случае можно просто разделить частоту термина в документе на количество документов, в которых он встречается.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np

# %%
c=[' '.join(getMeaningfullWords(n)) for n in lenta.articles]

tfCounter=TfidfVectorizer(ngram_range=(1,2), token_pattern=r'[А-Яа-яЁё]+\-[А-Яа-яЁё]+|[А-Яа-яЁё]+')

analyze = tfCounter.build_analyzer()
res=tfCounter.fit_transform(c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-096461e0ca74> in <module>()
# ----> 1 c=[' '.join(getMeaningfullWords(n)) for n in lenta.articles]
#       2
#       3 tfCounter=TfidfVectorizer(ngram_range=(1,2), token_pattern=r'[А-Яа-яЁё]+\-[А-Яа-яЁё]+|[А-Яа-яЁё]+')
#       4
#       5 analyze = tfCounter.build_analyzer()
#
# <ipython-input-28-096461e0ca74> in <listcomp>(.0)
# ----> 1 c=[' '.join(getMeaningfullWords(n)) for n in lenta.articles]
#       2
#       3 tfCounter=TfidfVectorizer(ngram_range=(1,2), token_pattern=r'[А-Яа-яЁё]+\-[А-Яа-яЁё]+|[А-Яа-яЁё]+')
#       4
#       5 analyze = tfCounter.build_analyzer()
#
# <ipython-input-18-e37935aefa19> in getMeaningfullWords(text)
#       3     tokens=re.findall('[А-Яа-яЁё]+\-[А-Яа-яЁё]+|[А-Яа-яЁё]+', text)
#       4     for t in tokens:
# ----> 5         pv=morph.parse(t)
#       6         for p in pv:
#       7             if p.tag.POS in ['ADJF', 'NOUN', 'VERB']:
#
# NameError: name 'morph' is not defined

# %%
id_article=6

res2=analyze(lenta.articles[id_article])
tfs=list(set(res[id_article][0, tfCounter.vocabulary_.get(k)] for k in res2 if k in tfCounter.vocabulary_.keys()))
tfs2=[k for k in tfs if k>np.average(tfs)]
#tfs2=[k for k in tfs if k>np.average(tfs)+np.std(tfs)]
print({w:res[id_article][0, tfCounter.vocabulary_[w]] for w in res2 if w in tfCounter.vocabulary_.keys() and res[id_article][0, tfCounter.vocabulary_[w]] in tfs2})
# Out:
# {'ближний': 0.09754172040483444, 'восток': 0.10389546512876865, 'платформа': 0.11428148479237515, 'жозе': 0.16535511285226273, 'увеличение': 0.0842033272150634, 'возможность': 0.08574845736217529, 'доставка': 0.13234427079429065, 'клиентский': 0.1744831264097395, 'сервис': 0.0709906385519639, 'услуга': 0.06742359087070612, 'ближний восток': 0.13825073355807999, 'клиентский сервис': 0.11632208427315967}
